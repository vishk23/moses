# %%
# Async Connector
# Developed by CD
# v2.0.0-prod

from io import StringIO
import time
import numpy as np
import os
from datetime import datetime, timedelta, date
from sqlalchemy.ext.asyncio import create_async_engine
from sqlalchemy import text
from typing import List
from collections import defaultdict, Counter
import pandas as pd
from cryptography.fernet import Fernet
from dotenv import load_dotenv
from io import StringIO
from pathlib import Path
import asyncio
import nest_asyncio
import sys
from typing import Dict, Union, List
nest_asyncio.apply()

if sys.platform == "win32":
    asyncio.set_event_loop_policy(asyncio.WindowsSelectorEventLoopPolicy())


def retrieve_data(queries: List[Dict[str, Union[str, pd.DataFrame, int]]]) -> Dict[str, pd.DataFrame]:
    """
    Retrieve data from Oracle Database (COCC)

    Args:
        queries (List): pass list of queries in specific format
            - List[Dict[str, Union[str, pd.DataFrame, int]]]
    
    Returns:
        data (Dict): Returns a dictionary with df name and the df attached as key/value pair.   

    """
    class DatabaseHandler:
        """
        This class abstracts the connection to the database and allows a clean
        interface for the developer to use.

        This connector can handle async queries

        """
        def __init__(self, tns_admin_path):
            """
            Args:
                tns_admin_path (str): Oracle driver path
                credentials_path_db1 (str): Database 1 credentials path
                credentials_path_db1 (str): Databsae 2 credentials path
            """
            os.environ['TNS_ADMIN'] = tns_admin_path

            project_root = os.getcwd()
            
            # Load private key
            key_key_path = 'env_admin\key.key'
            with open(key_key_path, "rb") as key_file:
                key = key_file.read()

            cipher = Fernet(key)
            
            # Load encrypted data
            encoded_env_path = r'env_admin\.env.enc'
            with open(encoded_env_path, "rb") as encrypted_file:
                encrypted_data = encrypted_file.read()

            decrypted_data = cipher.decrypt(encrypted_data).decode()

            env_file = StringIO(decrypted_data)
            load_dotenv(stream=env_file)

            self.username1 = os.getenv('main_username')
            self.password1 = os.getenv('main_password')
            self.dsn1 = os.getenv('main_dsn')

            self.username2 = os.getenv('datamart_username')
            self.password2 = os.getenv('datamart_password')
            self.dsn2 = os.getenv('datamart_dsn')

            self.connection_string1 = f'oracle+oracledb://{self.username1}:{self.password1}@{self.dsn1}'
            self.connection_string2 = f'oracle+oracledb://{self.username2}:{self.password2}@{self.dsn2}'

            self.engine1 = create_async_engine(self.connection_string1, max_identifier_length=128, echo=False, future=True)
            self.engine1.dialect.hide_parameters = True
            self.engine2 = create_async_engine(self.connection_string2, max_identifier_length=128, echo=False, future=True)
            self.engine1.dialect.hide_parameters = True


        async def query(self, sql_query, engine=1):
            """
            This allows abstraction of the connection and the class
            so the developer can query a single table as a dataframe

            Args:
                sql_query (str): The query to SQL database is passed as a string
                engine (int): This selects the database. There are two engines:
                    1 -> R1625
                    2 -> COCC DataMart

            Returns:
                df: The SQL query is returned as a pandas DataFrame

            Usage:
                df = db_handler.query("SELECT * FROM DB.TABLE", engine=1)

                In this example, db_handler = DatabaseHandler(args)
            """
            if engine == 1:
                selected_engine = self.engine1
            elif engine == 2:
                selected_engine = self.engine2
            else:
                raise ValueError("Engine must be 1 or 2")

            async with selected_engine.connect() as connection:
                result = await connection.execute(sql_query)
                rows = result.fetchall()
                if not rows:
                    return pd.DataFrame()
                df = pd.DataFrame(rows, columns=result.keys())
            return df

        async def close(self):
            if self.engine1:
                await self.engine1.dispose()
            if self.engine2:
                await self.engine2.dispose()


    # Database Connection Configuration
    tns_admin_path = r'env_admin\tns_admin'
    db_handler = DatabaseHandler(tns_admin_path)

    async def fetch_data(queries):
        try:
            tasks = {query['key']: asyncio.create_task(db_handler.query(query['sql'], query['engine'])) for query in queries}
            results = await asyncio.gather(*tasks.values())
            return {key: df for key, df in zip(tasks.keys(), results)}
        except Exception as e:
            print(f"Error")
            raise
        finally:
            await db_handler.close()

    def run_sql_queries(queries):

        async def run_queries():
            return await fetch_data(queries)
        
        loop = asyncio.get_event_loop()
        if loop.is_running():
            return loop.run_until_complete(run_queries())
        else:
            return asyncio.run(run_queries())
        
    data = run_sql_queries(queries)
    
    return data

# %%
# lookup table
# Engine 1
lookup_df = text("""
SELECT 
    *
FROM 
    sys.all_tab_columns col
""")

queries = [
    # {'key':'acctcommon', 'sql':acctcommon, 'engine':2},
    {'key':'lookup_df', 'sql':lookup_df, 'engine':2},
]

data = retrieve_data(queries)
lookup_df = data['lookup_df'].copy()

# %%
lookup_df
# Out:
#       owner                table_name column_name data_type data_type_mod  \
# 0       XDB        XDB$IMPORT_TT_INFO          ID       RAW          None
# 1       XDB        XDB$IMPORT_TT_INFO       FLAGS       RAW          None
# 2       XDB        XDB$IMPORT_TT_INFO   LOCALNAME  VARCHAR2          None
# 3       XDB        XDB$IMPORT_TT_INFO     NMSPCID       RAW          None
# 4       XDB        XDB$IMPORT_TT_INFO        GUID       RAW          None
# ...     ...                       ...         ...       ...           ...
# 28688   SYS  USER_XML_SCHEMA_ELEMENTS      GLOBAL       RAW          None
# 28689   SYS            KU$_ASSOC_VIEW    OBJ_TYPE    NUMBER          None
# 28690   SYS                  EXU8VEWU       DEFER    NUMBER          None
# 28691   SYS             KU$_USER_VIEW  VERS_MAJOR      CHAR          None
# 28692   SYS  _USER_COMPARISON_ROW_DIF   LOC_ROWID     ROWID          None
#
#       data_type_owner  data_length  data_precision  data_scale nullable  ...  \
# 0                None            8             NaN         NaN        Y  ...
# 1                None            4             NaN         NaN        Y  ...
# 2                None         2000             NaN         NaN        Y  ...
# 3                None            8             NaN         NaN        Y  ...
# 4                None           16             NaN         NaN        Y  ...
# ...               ...          ...             ...         ...      ...  ...
# 28688            None            1             NaN         NaN        Y  ...
# 28689            None           22             NaN         NaN        Y  ...
# 28690            None           22             NaN         NaN        Y  ...
# 28691            None            1             NaN         NaN        Y  ...
# 28692            None           10             NaN         NaN        Y  ...
#
#        char_used  v80_fmt_image data_upgraded  histogram default_on_null  \
# 0           None             NO           YES       NONE              NO
# 1           None             NO           YES       NONE              NO
# 2              B             NO           YES       NONE              NO
# 3           None             NO           YES       NONE              NO
# 4           None             NO           YES       NONE              NO
# ...          ...            ...           ...        ...             ...
# 28688       None             NO           YES       NONE              NO
# 28689       None             NO           YES       NONE              NO
# 28690       None             NO           YES       NONE              NO
# 28691          B             NO           YES       NONE              NO
# 28692       None             NO           YES       NONE              NO
#
#       identity_column evaluation_edition  unusable_before  unusable_beginning  \
# 0                  NO               None             None                None
# 1                  NO               None             None                None
# 2                  NO               None             None                None
# 3                  NO               None             None                None
# 4                  NO               None             None                None
# ...               ...                ...              ...                 ...
# 28688              NO               None             None                None
# 28689              NO               None             None                None
# 28690              NO               None             None                None
# 28691              NO               None             None                None
# 28692              NO               None             None                None
#
#             collation
# 0                None
# 1                None
# 2      USING_NLS_COMP
# 3                None
# 4                None
# ...               ...
# 28688            None
# 28689            None
# 28690            None
# 28691  USING_NLS_COMP
# 28692            None
#
# [28693 rows x 37 columns]

# %%
# lookup table
# Engine 1
acctcommon = text("""
SELECT 
    *
FROM 
    OSIBANK.PERS
""")

queries = [
    {'key':'acctcommon', 'sql':acctcommon, 'engine':1},
    # {'key':'wh_pers', 'sql':wh_pers, 'engine':1},
    # {'key':'loans', 'sql':loans, 'engine':1},
    # {'key':'househldacct', 'sql':househldacct, 'engine':1},
    # {'key':'allroles', 'sql':allroles, 'engine':1},
    # {'key':'persaddruse', 'sql':persaddruse, 'engine':1},
    # {'key':'wh_addr', 'sql':wh_addr, 'engine':1},
    # {'key':'pers', 'sql':pers, 'engine':1},
    # {'key':'acctstatistichist', 'sql':acctstatistichist, 'engine':1},
    # {'key':'acctloanlimithist', 'sql':acctloanlimithist, 'engine':1},
]

data = retrieve_data(queries)
pers = data['pers'].copy()

# %%
pers
# Out:
#         persnbr  spousepersnbr restaxctrycd  crcd salucd         lastname  \
# 0           127            NaN          USA  None   None             COCC
# 1           180            NaN          USA  None   None             COCC
# 2           181            NaN          USA  None   None             COCC
# 3           182            NaN          USA  None   None             COCC
# 4           184            NaN          USA  None   None             COCC
# ...         ...            ...          ...   ...    ...              ...
# 163959  1167967            NaN          USA  None   None  RAMDHANY CORREA
# 163960  1167973            NaN          USA  None   None           MURPHY
# 163961  1167983            NaN          USA  None   None     COLON TORRES
# 163962  1167985            NaN          USA  None   None         DEFONTES
# 163963  1168012            NaN          USA  None   None           OBRIEN
#
#        lastnamesndx firstname firstnamesndx mdlinit  ... firstnameupper  \
# 0              C200  DEPOSIT8          D123    None  ...       DEPOSIT8
# 1              C200     ROCH2          R200    None  ...          ROCH2
# 2              C200     ROCH3          R200    None  ...          ROCH3
# 3              C200     ROCH4          R200    None  ...          ROCH4
# 4              C200    PRINT6          P653    None  ...         PRINT6
# ...             ...       ...           ...     ...  ...            ...
# 163959         R535    JESSIE          J200    None  ...         JESSIE
# 163960         M610    THOMAS          T520       G  ...         THOMAS
# 163961         C453    VICTOR          V236       M  ...         VICTOR
# 163962         D153      JOHN          J500       R  ...           JOHN
# 163963         O165   STEPHEN          S315       T  ...        STEPHEN
#
#        rpt1042syn graddate creditreportconsinfocd privacyyn purgeyn shortname  \
# 0               N      NaT                   None         N       N      None
# 1               N      NaT                   None         N       N      None
# 2               N      NaT                   None         N       N      None
# 3               N      NaT                   None         N       N      None
# 4               N      NaT                   None         N       N      None
# ...           ...      ...                    ...       ...     ...       ...
# 163959          N      NaT                   None         N       N      None
# 163960          N      NaT                   None         N       N      None
# 163961          N      NaT                   None         N       N      None
# 163962          N      NaT                   None         N       N      None
# 163963          N      NaT                   None         N       N      None
#
#        prefculturecd secondsurname deathnotificationdate
# 0               None          None                   NaT
# 1               None          None                   NaT
# 2               None          None                   NaT
# 3               None          None                   NaT
# 4               None          None                   NaT
# ...              ...           ...                   ...
# 163959          None          None                   NaT
# 163960          None          None                   NaT
# 163961          None          None                   NaT
# 163962          None          None                   NaT
# 163963          None          None                   NaT
#
# [163964 rows x 40 columns]

# %%
acctloan = text("""
SELECT 
    *
FROM 
    OSIBANK.WH_ACCTLOAN
""")

queries = [
    {'key':'acctloan', 'sql':acctloan, 'engine':1},
    # {'key':'wh_pers', 'sql':wh_pers, 'engine':1},
    # {'key':'loans', 'sql':loans, 'engine':1},
    # {'key':'househldacct', 'sql':househldacct, 'engine':1},
    # {'key':'allroles', 'sql':allroles, 'engine':1},
    # {'key':'persaddruse', 'sql':persaddruse, 'engine':1},
    # {'key':'wh_addr', 'sql':wh_addr, 'engine':1},
    # {'key':'pers', 'sql':pers, 'engine':1},
    # {'key':'acctstatistichist', 'sql':acctstatistichist, 'engine':1},
    # {'key':'acctloanlimithist', 'sql':acctloanlimithist, 'engine':1},
]

data = retrieve_data(queries)
acctloan = data['acctloan'].copy()

# %%
acctloan

# %%
lookup_df[lookup_df['column_name'].str.contains('credlimitclat',case=False,na=False)]
# Out:
#        owner        table_name              column_name data_type  \
# 1629  COCCDM       WH_ACCTLOAN  CREDLIMITCLATRESEFFDATE      DATE
# 1630  COCCDM       WH_ACCTLOAN      CREDLIMITCLATRESAMT    NUMBER
# 1748  COCCDM  WH_ACCTLOAN_TEMP  CREDLIMITCLATRESEFFDATE      DATE
# 1749  COCCDM  WH_ACCTLOAN_TEMP      CREDLIMITCLATRESAMT    NUMBER
# 5621  COCCDM    WH_ACCTLOAN_ME  CREDLIMITCLATRESEFFDATE      DATE
# 5622  COCCDM    WH_ACCTLOAN_ME      CREDLIMITCLATRESAMT    NUMBER
#
#      data_type_mod data_type_owner  data_length  data_precision  data_scale  \
# 1629          None            None            7             NaN         NaN
# 1630          None            None           22            22.0         3.0
# 1748          None            None            7             NaN         NaN
# 1749          None            None           22            22.0         3.0
# 5621          None            None            7             NaN         NaN
# 5622          None            None           22            22.0         3.0
#
#      nullable  ...  char_used  v80_fmt_image data_upgraded  histogram  \
# 1629        Y  ...       None             NO           YES       NONE
# 1630        Y  ...       None             NO           YES       NONE
# 1748        Y  ...       None             NO           YES       NONE
# 1749        Y  ...       None             NO           YES       NONE
# 5621        Y  ...       None             NO           YES       NONE
# 5622        Y  ...       None             NO           YES       NONE
#
#      default_on_null identity_column evaluation_edition  unusable_before  \
# 1629              NO              NO               None             None
# 1630              NO              NO               None             None
# 1748              NO              NO               None             None
# 1749              NO              NO               None             None
# 5621              NO              NO               None             None
# 5622              NO              NO               None             None
#
#       unusable_beginning collation
# 1629                None      None
# 1630                None      None
# 1748                None      None
# 1749                None      None
# 5621                None      None
# 5622                None      None
#
# [6 rows x 37 columns]

# %%
prop_tables = lookup_df[lookup_df['table_name'].str.contains('prop',case=False,na=False)]

# %%
prop_tables['table_name'].unique()
# Out:
# array(['ACCTPROPINS', 'AU_XFR_ENTCHANGESETPROPERTY_V',
#        'AU_XFR_ENTITYCHANGESETPROPERTY', 'AU_XFR_ENTITYPROPERTY',
#        'PROPUSERFIELD', 'WH_PROP', 'WH_PROP2', 'WH_PROPUSERFIELDS',
#        'VIEW_WH_PROPUSERFIELDS', 'ALL_PROPAGATION', 'KU$_MVPROP_VIEW',
#        'ALL_METADATA_PROPERTIES', 'KU$_REFPARTTABPROP_VIEW',
#        'CDB_DBFS_HS_FIXED_PROPERTIES', 'DATABASE_PROPERTIES',
#        'USER_METADATA_PROPERTIES', 'USER_DBFS_HS_FIXED_PROPERTIES',
#        'KU$_TABPROP_VIEW', 'KU$_MVLPROP_VIEW', 'KU$_PFHTABPROP_VIEW',
#        'DBA_DBFS_HS_FIXED_PROPERTIES', 'KU$_VIEWPROP_VIEW',
#        'USER_DBFS_HS_PROPERTIES', 'KU$_MZPROP_VIEW'], dtype=object)

# %%
prop_tables[prop_tables['table_name'] == 'ACCTPROPINS']
# Out:
#      owner   table_name     column_name data_type data_type_mod  \
# 88  COCCDM  ACCTPROPINS         PROPNBR    NUMBER          None
# 89  COCCDM  ACCTPROPINS  LENDERFUNDEDYN      CHAR          None
# 90  COCCDM  ACCTPROPINS   INTRPOLICYNBR    NUMBER          None
# 91  COCCDM  ACCTPROPINS    INACTIVEDATE      DATE          None
# 92  COCCDM  ACCTPROPINS        ESCROWYN      CHAR          None
# 93  COCCDM  ACCTPROPINS         EFFDATE      DATE          None
# 94  COCCDM  ACCTPROPINS   DATELASTMAINT      DATE          None
# 95  COCCDM  ACCTPROPINS         ACCTNBR    NUMBER          None
#
#    data_type_owner  data_length  data_precision  data_scale nullable  ...  \
# 88            None           22            22.0         0.0        N  ...
# 89            None            1             NaN         NaN        N  ...
# 90            None           22            22.0         0.0        N  ...
# 91            None            7             NaN         NaN        Y  ...
# 92            None            1             NaN         NaN        N  ...
# 93            None            7             NaN         NaN        Y  ...
# 94            None            7             NaN         NaN        N  ...
# 95            None           22            22.0         0.0        N  ...
#
#     char_used  v80_fmt_image data_upgraded        histogram default_on_null  \
# 88       None             NO           YES  HEIGHT BALANCED              NO
# 89          B             NO           YES             NONE              NO
# 90       None             NO           YES             NONE              NO
# 91       None             NO           YES             NONE              NO
# 92          B             NO           YES             NONE              NO
# 93       None             NO           YES             NONE              NO
# 94       None             NO           YES             NONE              NO
# 95       None             NO           YES             NONE              NO
#
#    identity_column evaluation_edition  unusable_before  unusable_beginning  \
# 88              NO               None             None                None
# 89              NO               None             None                None
# 90              NO               None             None                None
# 91              NO               None             None                None
# 92              NO               None             None                None
# 93              NO               None             None                None
# 94              NO               None             None                None
# 95              NO               None             None                None
#
#          collation
# 88            None
# 89  USING_NLS_COMP
# 90            None
# 91            None
# 92  USING_NLS_COMP
# 93            None
# 94            None
# 95            None
#
# [8 rows x 37 columns]

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent.parent))
import main

data = main.fetch_data()
file_path = Path(r'Z:\Chad Projects\Monthly Reports\Automated Linda Reports\NonOwnerOcc\Production\output')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 5
#       2 from pathlib import Path
#       4 sys.path.append(str(Path.cwd().parent.parent))
# ----> 5 import main
#       7 data = main.fetch_data()
#       8 file_path = Path(r'Z:\Chad Projects\Monthly Reports\Automated Linda Reports\NonOwnerOcc\Production\output')
#
# ModuleNotFoundError: No module named 'main'

# %%
os.getcwd()
# Out:
# 'z:\\Chad Projects\\Monthly Reports\\Automated Linda Reports\\NonOwnerOcc\\Production\\src\\data_connection'
