# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# %%
INPUT_PATH = Path(r"Z:\Credit_Loan_Review\Alerts\Development\bin\06-26-25- ALERTS RESULTS & NOTES.xlsx")

# %%
df = pd.read_excel(INPUT_PATH, sheet_name='DATA')
# Out:
# c:\Users\w322800\Documents\coding3\.venv\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
df
# Out:
#                  Outcome  New Inactive Date  \
# 0   PASS-RENEW NEXT YEAR                NaN
# 1   PASS-RENEW NEXT YEAR                NaN
# 2   PASS-RENEW NEXT YEAR                NaN
# 3   PASS-RENEW NEXT YEAR                NaN
# 4   PASS-RENEW NEXT YEAR                NaN
# ..                   ...                ...
# 60  PASS-RENEW NEXT YEAR                NaN
# 61  PASS-RENEW NEXT YEAR                NaN
# 62  PASS-RENEW NEXT YEAR                NaN
# 63  PASS-RENEW NEXT YEAR                NaN
# 64  PASS-RENEW NEXT YEAR                NaN
#
#     Act. to charge for $100 renewal fee  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ..                                  ...
# 60                                  NaN
# 61                                  NaN
# 62                                  NaN
# ...

# %%
df["Outcome"].value_counts()
# Out:
# Outcome
# PASS-RENEW NEXT YEAR      57
# FAIL-FULL REVIEW           5
# PASS-NEXT QUARTER ONLY     3
# Name: count, dtype: int64

# %%
df['acctnbr'].nunique()
# Out:
# 65

# %%
employee_hours_per_renewal = 8

# %%
passed_by_alerts = 60

# %%
avg_rate = 45

# %%
quarterly = employee_hours_per_renewal * passed_by_alerts * avg_rate

# %%
annualized_alerts_savings = quarterly*4

# %%
annualized_alerts_savings
# Out:
# 86400
