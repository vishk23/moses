# %%
## Memorializing this as the easy way to lookup accounts

# %%
"""
Main Entry Point
"""
from pathlib import Path
from typing import List
import argparse
from datetime import datetime

import pandas as pd # type: ignore

import src.fetch_data # type: ignore
import src.core_transform # type: ignore
import cdutils.pkey_sqlite # type: ignore
import cdutils.hhnbr # type: ignore

# Current (doesn't really work without)
# data = src.fetch_data.fetch_data()


# Specific date
specified_date = datetime(2020, 12, 31)
data = src.fetch_data.fetch_data(specified_date)

# # # Core transformation pipeline
raw_data = src.core_transform.main_pipeline(data)

# Raw data with pkey appended
raw_data = cdutils.pkey_sqlite.add_pkey(raw_data)
raw_data = cdutils.pkey_sqlite.add_ownership_key(raw_data)
raw_data = cdutils.pkey_sqlite.add_address_key(raw_data)
# Out:
# Column 'acctnbr' not found. Creating it with default None values.
# Column 'acctnbr' not found. Creating it with default None values.
# Column 'acctnbr' not found. Creating it with default None values.
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x0000027645DC7FD0>>
# Traceback (most recent call last):
#   File "c:\Users\w322800\Documents\orchestr8\.venv\Lib\site-packages\ipykernel\ipkernel.py", line 790, in _clean_thread_parent_frames
#     active_threads = {thread.ident for thread in threading.enumerate()}
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\w322800\Documents\orchestr8\.venv\Lib\site-packages\ipykernel\ipkernel.py", line 790, in <setcomp>
#     active_threads = {thread.ident for thread in threading.enumerate()}
#                       ^^^^^^^^^^^^
#   File "C:\Users\w322800\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1168, in ident
#     @property
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\w322800\Documents\orchestr8\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'bookbalance'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 25
#      17 data = src.fetch_data.fetch_data()
#      20 # # Specific date
#      21 # specified_date = datetime(2025, 6, 30)
#      22 # data = src.fetch_data.fetch_data(specified_date)
#      23
#      24 # # # Core transformation pipeline
# ---> 25 raw_data = src.core_transform.main_pipeline(data)
#      27 # Raw data with pkey appended
#      28 raw_data = cdutils.pkey_sqlite.add_pkey(raw_data)
#
# File z:\Data_Analytics\Libraries\cdutils\cdutils\acct_lookup_any_date\src\core_transform.py:43, in main_pipeline(data)
#      39 main_loan_data = cdutils.joining.join_loan_tables(wh_acctcommon, wh_acctloan, wh_loans)
#      40 # property_data = src.transformations.joining.join_prop_tables(wh_prop, wh_prop2)
#      41
#      42 # # Calculated fields & data cleaning
# ---> 43 main_loan_data = cdutils.loans.calculations.append_total_exposure_field(main_loan_data)
#      44 main_loan_data = cdutils.loans.calculations.cleaning_loan_data(main_loan_data)
#      46 # Consolidate loan data & property data
#      47 # single_prop_data = src.transformations.joining.consolidation_with_one_prop(main_loan_data, property_data)
#      48 # multiple_prop_data = src.transformations.joining.consolidation_with_multiple_props(main_loan_data, property_data)
#      49
#      50 # Sort data
#
# File \\00-da1\Home\Share\Data & Analytics Initiatives\Project Management\Data_Analytics\Libraries\cdutils\cdutils\loans\calculations.py:26, in append_total_exposure_field(df)
#      24 list_of_numeric = ['bookbalance','notebal','availbalamt','totalpctsold','noteopenamt','creditlimitamt','noteintrate','cobal','credlimitclatresamt']
#      25 for col in list_of_numeric:
# ---> 26     df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0)
#      28 def convert_to_float(value):
#      29     try:
#
# File c:\Users\w322800\Documents\orchestr8\.venv\Lib\site-packages\pandas\core\frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File c:\Users\w322800\Documents\orchestr8\.venv\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'bookbalance'

# %%
househldacct = data['househldacct'].copy()
raw_data = cdutils.hhnbr.add_hh_nbr(raw_data, househldacct)

# %%
raw_data
# Out:
#          effdate    acctnbr                  ownersortname  \
# 0     2025-06-30  150200005  MONEYGRAM PAYMENT SYSTEMS INC
# 1     2025-06-30  150936915        REDBROOK APARTMENTS LLC
# 2     2025-06-30  151058057             NBPIV SARATOGA LLC
# 3     2025-06-30  150988429              CITY OF ATTLEBORO
# 4     2025-06-30  150887241                CITY OF TAUNTON
# ...          ...        ...                            ...
# 89800 2025-06-30   28163508                 COSMO, JOEL A.
# 89801 2025-06-30   27047636    BRISTOL COUNTY SAVINGS BANK
# 89802 2025-06-30   27039064    BRISTOL COUNTY SAVINGS BANK
# 89803 2025-06-30   27020568    BRISTOL COUNTY SAVINGS BANK
# 89804 2025-06-30  150337783    BRISTOL COUNTY SAVINGS BANK
#
#                             product  noteopenamt ratetypcd mjaccttypcd  \
# 0                 Treasurer's Check          0.0      None        BKCK
# 1              Commercial Mortgages   65500000.0       VAR         CML
# 2              Commercial Mortgages   26000000.0       FIX         CML
# 3        ICS Shadow - Muni - Demand          0.0      None          CK
# 4      ICS Shadow - Muni - MMDA/SAV          0.0      None          CK
# ...                             ...          ...       ...         ...
# 89800           Prime Time Checking          0.0       VAR          CK
# 89801               Payoff Overages          0.0      None        BKCK
# 89802      Escrow Checks Processing          0.0      None        BKCK
# 89803              PDO Checks - OLD          0.0      None        BKCK
# 89804             Business Checking          0.0      None          CK
#
#       currmiaccttypcd curracctstatcd  noteintrate  ...   Net Balance  \
# 0                TRCK            ACT     0.000000  ...  1.594158e+09
# 1                CM40            ACT     0.065722  ...  2.900000e+07
# 2                CM40            ACT     0.063500  ...  2.600000e+07
# 3                CK36            ACT     0.000000  ...  2.591128e+07
# 4                CK42            ACT     0.000000  ...  2.551224e+07
# ...               ...            ...          ...  ...           ...
# 89800            CK06            ACT     0.000300  ... -1.156100e+03
# 89801            BTC2            ACT     0.000000  ... -2.098590e+03
# 89802            BTC3            ACT     0.000000  ... -7.325560e+04
# 89803            BTC1            ACT     0.000000  ... -2.041281e+05
# 89804            CK12            ACT     0.000000  ... -5.707518e+05
#
#        Net Available Net Collateral Reserve Total Exposure  orig_ttl_loan_amt  \
# 0                0.0                    0.0   1.594158e+09                0.0
# 1                0.0                    0.0   2.900000e+07         65500000.0
# 2                0.0                    0.0   2.600000e+07         26000000.0
# 3                0.0                    0.0   2.591128e+07                0.0
# 4                0.0                    0.0   2.551224e+07                0.0
# ...              ...                    ...            ...                ...
# 89800            0.0                    0.0  -1.156100e+03                0.0
# 89801            0.0                    0.0  -2.098590e+03                0.0
# 89802            0.0                    0.0  -7.325560e+04                0.0
# 89803            0.0                    0.0  -2.041281e+05                0.0
# 89804            0.0                    0.0  -5.707518e+05                0.0
#
#        portfolio_key ownership_key address_key  householdnbr  \
# 0              41516       43261.0     44260.0      187340.0
# 1              57113       59661.0     61147.0      193906.0
# 2              79217       83546.0     85431.0      288455.0
# 3               5106       35118.0     35620.0           NaN
# 4               4183       33668.0     33967.0           NaN
# ...              ...           ...         ...           ...
# 89800          40467       41934.0     42975.0      112816.0
# 89801           1221        1352.0     41645.0      255924.0
# 89802           1221        1352.0     41577.0      255924.0
# 89803           1221        1352.0     41437.0      255924.0
# 89804           1221        1352.0     51094.0      255924.0
#
#             datelastmaint
# 0     2020-02-26 23:28:03
# 1     2023-09-22 08:01:38
# 2     2024-06-11 12:02:04
# 3                     NaT
# 4                     NaT
# ...                   ...
# 89800 2020-02-26 23:27:59
# 89801 2022-09-27 22:46:27
# 89802 2022-09-27 22:46:27
# 89803 2022-09-27 22:46:27
# 89804 2022-09-27 22:46:27
#
# [89805 rows x 45 columns]

# %%
import cdutils.loans.calculations

# %%
loan_category_df = cdutils.loans.calculations.categorize_loans(raw_data)

# %%
loan_category_df = loan_category_df[['acctnbr','Category']].copy()

# %%
df = pd.merge(raw_data, loan_category_df, on='acctnbr', how='left')

# %%
df
# Out:
#          effdate    acctnbr                  ownersortname  \
# 0     2025-06-30  150200005  MONEYGRAM PAYMENT SYSTEMS INC
# 1     2025-06-30  150936915        REDBROOK APARTMENTS LLC
# 2     2025-06-30  151058057             NBPIV SARATOGA LLC
# 3     2025-06-30  150988429              CITY OF ATTLEBORO
# 4     2025-06-30  150887241                CITY OF TAUNTON
# ...          ...        ...                            ...
# 89800 2025-06-30   28163508                 COSMO, JOEL A.
# 89801 2025-06-30   27047636    BRISTOL COUNTY SAVINGS BANK
# 89802 2025-06-30   27039064    BRISTOL COUNTY SAVINGS BANK
# 89803 2025-06-30   27020568    BRISTOL COUNTY SAVINGS BANK
# 89804 2025-06-30  150337783    BRISTOL COUNTY SAVINGS BANK
#
#                             product  noteopenamt ratetypcd mjaccttypcd  \
# 0                 Treasurer's Check          0.0      None        BKCK
# 1              Commercial Mortgages   65500000.0       VAR         CML
# 2              Commercial Mortgages   26000000.0       FIX         CML
# 3        ICS Shadow - Muni - Demand          0.0      None          CK
# 4      ICS Shadow - Muni - MMDA/SAV          0.0      None          CK
# ...                             ...          ...       ...         ...
# 89800           Prime Time Checking          0.0       VAR          CK
# 89801               Payoff Overages          0.0      None        BKCK
# 89802      Escrow Checks Processing          0.0      None        BKCK
# 89803              PDO Checks - OLD          0.0      None        BKCK
# 89804             Business Checking          0.0      None          CK
#
#       currmiaccttypcd curracctstatcd  noteintrate  ...  Net Available  \
# 0                TRCK            ACT     0.000000  ...            0.0
# 1                CM40            ACT     0.065722  ...            0.0
# 2                CM40            ACT     0.063500  ...            0.0
# 3                CK36            ACT     0.000000  ...            0.0
# 4                CK42            ACT     0.000000  ...            0.0
# ...               ...            ...          ...  ...            ...
# 89800            CK06            ACT     0.000300  ...            0.0
# 89801            BTC2            ACT     0.000000  ...            0.0
# 89802            BTC3            ACT     0.000000  ...            0.0
# 89803            BTC1            ACT     0.000000  ...            0.0
# 89804            CK12            ACT     0.000000  ...            0.0
#
#        Net Collateral Reserve Total Exposure orig_ttl_loan_amt  portfolio_key  \
# 0                         0.0   1.594158e+09               0.0          41516
# 1                         0.0   2.900000e+07        65500000.0          57113
# 2                         0.0   2.600000e+07        26000000.0          79217
# 3                         0.0   2.591128e+07               0.0           5106
# 4                         0.0   2.551224e+07               0.0           4183
# ...                       ...            ...               ...            ...
# 89800                     0.0  -1.156100e+03               0.0          40467
# 89801                     0.0  -2.098590e+03               0.0           1221
# 89802                     0.0  -7.325560e+04               0.0           1221
# 89803                     0.0  -2.041281e+05               0.0           1221
# 89804                     0.0  -5.707518e+05               0.0           1221
#
#        ownership_key address_key householdnbr       datelastmaint Category
# 0            43261.0     44260.0     187340.0 2020-02-26 23:28:03      NaN
# 1            59661.0     61147.0     193906.0 2023-09-22 08:01:38      CRE
# 2            83546.0     85431.0     288455.0 2024-06-11 12:02:04      CRE
# 3            35118.0     35620.0          NaN                 NaT      NaN
# 4            33668.0     33967.0          NaN                 NaT      NaN
# ...              ...         ...          ...                 ...      ...
# 89800        41934.0     42975.0     112816.0 2020-02-26 23:27:59      NaN
# 89801         1352.0     41645.0     255924.0 2022-09-27 22:46:27      NaN
# 89802         1352.0     41577.0     255924.0 2022-09-27 22:46:27      NaN
# 89803         1352.0     41437.0     255924.0 2022-09-27 22:46:27      NaN
# 89804         1352.0     51094.0     255924.0 2022-09-27 22:46:27      NaN
#
# [89805 rows x 46 columns]

# %%
import cdutils.inactive_date

df = cdutils.inactive_date.append_inactive_date(df)

# %%
df
# Out:
#          effdate    acctnbr                  ownersortname  \
# 0     2025-06-30  150200005  MONEYGRAM PAYMENT SYSTEMS INC
# 1     2025-06-30  150936915        REDBROOK APARTMENTS LLC
# 2     2025-06-30  151058057             NBPIV SARATOGA LLC
# 3     2025-06-30  150988429              CITY OF ATTLEBORO
# 4     2025-06-30  150887241                CITY OF TAUNTON
# ...          ...        ...                            ...
# 89800 2025-06-30   28163508                 COSMO, JOEL A.
# 89801 2025-06-30   27047636    BRISTOL COUNTY SAVINGS BANK
# 89802 2025-06-30   27039064    BRISTOL COUNTY SAVINGS BANK
# 89803 2025-06-30   27020568    BRISTOL COUNTY SAVINGS BANK
# 89804 2025-06-30  150337783    BRISTOL COUNTY SAVINGS BANK
#
#                             product  noteopenamt ratetypcd mjaccttypcd  \
# 0                 Treasurer's Check          0.0      None        BKCK
# 1              Commercial Mortgages   65500000.0       VAR         CML
# 2              Commercial Mortgages   26000000.0       FIX         CML
# 3        ICS Shadow - Muni - Demand          0.0      None          CK
# 4      ICS Shadow - Muni - MMDA/SAV          0.0      None          CK
# ...                             ...          ...       ...         ...
# 89800           Prime Time Checking          0.0       VAR          CK
# 89801               Payoff Overages          0.0      None        BKCK
# 89802      Escrow Checks Processing          0.0      None        BKCK
# 89803              PDO Checks - OLD          0.0      None        BKCK
# 89804             Business Checking          0.0      None          CK
#
#       currmiaccttypcd curracctstatcd  noteintrate  ...  \
# 0                TRCK            ACT     0.000000  ...
# 1                CM40            ACT     0.065722  ...
# 2                CM40            ACT     0.063500  ...
# 3                CK36            ACT     0.000000  ...
# 4                CK42            ACT     0.000000  ...
# ...               ...            ...          ...  ...
# 89800            CK06            ACT     0.000300  ...
# 89801            BTC2            ACT     0.000000  ...
# 89802            BTC3            ACT     0.000000  ...
# 89803            BTC1            ACT     0.000000  ...
# 89804            CK12            ACT     0.000000  ...
#
#        Net Collateral Reserve  Total Exposure orig_ttl_loan_amt portfolio_key  \
# 0                         0.0    1.594158e+09               0.0         41516
# 1                         0.0    2.900000e+07        65500000.0         57113
# 2                         0.0    2.600000e+07        26000000.0         79217
# 3                         0.0    2.591128e+07               0.0          5106
# 4                         0.0    2.551224e+07               0.0          4183
# ...                       ...             ...               ...           ...
# 89800                     0.0   -1.156100e+03               0.0         40467
# 89801                     0.0   -2.098590e+03               0.0          1221
# 89802                     0.0   -7.325560e+04               0.0          1221
# 89803                     0.0   -2.041281e+05               0.0          1221
# 89804                     0.0   -5.707518e+05               0.0          1221
#
#        ownership_key  address_key householdnbr       datelastmaint  Category  \
# 0            43261.0      44260.0     187340.0 2020-02-26 23:28:03       NaN
# 1            59661.0      61147.0     193906.0 2023-09-22 08:01:38       CRE
# 2            83546.0      85431.0     288455.0 2024-06-11 12:02:04       CRE
# 3            35118.0      35620.0          NaN                 NaT       NaN
# 4            33668.0      33967.0          NaN                 NaT       NaN
# ...              ...          ...          ...                 ...       ...
# 89800        41934.0      42975.0     112816.0 2020-02-26 23:27:59       NaN
# 89801         1352.0      41645.0     255924.0 2022-09-27 22:46:27       NaN
# 89802         1352.0      41577.0     255924.0 2022-09-27 22:46:27       NaN
# 89803         1352.0      41437.0     255924.0 2022-09-27 22:46:27       NaN
# 89804         1352.0      51094.0     255924.0 2022-09-27 22:46:27       NaN
#
#       inactivedate
# 0              NaT
# 1              NaT
# 2              NaT
# 3              NaT
# 4              NaT
# ...            ...
# 89800          NaT
# 89801          NaT
# 89802          NaT
# 89803          NaT
# 89804          NaT
#
# [89805 rows x 47 columns]

# %%
pers = data['wh_pers'].copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89805 entries, 0 to 89804
# Data columns (total 47 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   effdate                 89805 non-null  datetime64[ns]
#  1   acctnbr                 89805 non-null  object
#  2   ownersortname           89805 non-null  object
#  3   product                 89805 non-null  object
#  4   noteopenamt             89805 non-null  float64
#  5   ratetypcd               71769 non-null  object
#  6   mjaccttypcd             89805 non-null  object
#  7   currmiaccttypcd         89805 non-null  object
#  8   curracctstatcd          89805 non-null  object
#  9   noteintrate             89805 non-null  float64
#  10  bookbalance             89805 non-null  float64
#  11  notebal                 89805 non-null  float64
#  12  contractdate            89804 non-null  datetime64[ns]
#  13  datemat                 33087 non-null  datetime64[ns]
#  14  taxrptfororgnbr         12441 non-null  float64
#  15  taxrptforpersnbr        77364 non-null  float64
#  16  loanofficer             23586 non-null  object
#  17  acctofficer             62733 non-null  object
#  18  creditlimitamt          89805 non-null  float64
#  19  origintrate             22892 non-null  object
#  20  marginfixed             23586 non-null  object
#  21  fdiccatcd               22955 non-null  object
#  22  amortterm               23586 non-null  float64
#  23  totalpctsold            89805 non-null  float64
#  24  cobal                   89805 non-null  float64
#  25  credlimitclatresamt     89805 non-null  float64
#  26  riskratingcd            2786 non-null   object
#  27  origdate                23402 non-null  datetime64[ns]
#  28  currterm                23586 non-null  float64
#  29  loanidx                 23575 non-null  object
#  30  rcf                     3005 non-null   object
#  31  availbalamt             89805 non-null  float64
#  32  fdiccatdesc             22955 non-null  object
#  33  origbal                 22714 non-null  float64
#  34  loanlimityn             23586 non-null  object
#  35  Net Balance             89805 non-null  float64
#  36  Net Available           89805 non-null  float64
#  37  Net Collateral Reserve  89805 non-null  float64
#  38  Total Exposure          89805 non-null  float64
#  39  orig_ttl_loan_amt       89805 non-null  float64
#  40  portfolio_key           89805 non-null  int64
#  41  ownership_key           88115 non-null  float64
#  42  address_key             88115 non-null  float64
#  43  householdnbr            80264 non-null  float64
#  44  datelastmaint           80264 non-null  datetime64[ns]
#  45  Category                23586 non-null  object
#  46  inactivedate            2545 non-null   datetime64[ns]
# dtypes: datetime64[ns](6), float64(22), int64(1), object(18)
# memory usage: 32.2+ MB

# %%
import src.additional_fields

additional_fields = src.additional_fields.fetch_data(specified_date)

# %%
additional_fields_to_append = additional_fields['wh_acctcommon'].copy()

# %%
import cdutils.input_cleansing

additional_fields_to_append_schema = {
    'acctnbr':'str'
}

additional_fields_to_append = cdutils.input_cleansing.enforce_schema(additional_fields_to_append, additional_fields_to_append_schema)

# %%
df = pd.merge(df, additional_fields_to_append, how='left', on='acctnbr')

# %%
df
# Out:
#          effdate    acctnbr                  ownersortname  \
# 0     2025-06-30  150200005  MONEYGRAM PAYMENT SYSTEMS INC
# 1     2025-06-30  150936915        REDBROOK APARTMENTS LLC
# 2     2025-06-30  151058057             NBPIV SARATOGA LLC
# 3     2025-06-30  150988429              CITY OF ATTLEBORO
# 4     2025-06-30  150887241                CITY OF TAUNTON
# ...          ...        ...                            ...
# 89800 2025-06-30   28163508                 COSMO, JOEL A.
# 89801 2025-06-30   27047636    BRISTOL COUNTY SAVINGS BANK
# 89802 2025-06-30   27039064    BRISTOL COUNTY SAVINGS BANK
# 89803 2025-06-30   27020568    BRISTOL COUNTY SAVINGS BANK
# 89804 2025-06-30  150337783    BRISTOL COUNTY SAVINGS BANK
#
#                             product  noteopenamt ratetypcd mjaccttypcd  \
# 0                 Treasurer's Check          0.0      None        BKCK
# 1              Commercial Mortgages   65500000.0       VAR         CML
# 2              Commercial Mortgages   26000000.0       FIX         CML
# 3        ICS Shadow - Muni - Demand          0.0      None          CK
# 4      ICS Shadow - Muni - MMDA/SAV          0.0      None          CK
# ...                             ...          ...       ...         ...
# 89800           Prime Time Checking          0.0       VAR          CK
# 89801               Payoff Overages          0.0      None        BKCK
# 89802      Escrow Checks Processing          0.0      None        BKCK
# 89803              PDO Checks - OLD          0.0      None        BKCK
# 89804             Business Checking          0.0      None          CK
#
#       currmiaccttypcd curracctstatcd  noteintrate  ...  portfolio_key  \
# 0                TRCK            ACT     0.000000  ...          41516
# 1                CM40            ACT     0.065722  ...          57113
# 2                CM40            ACT     0.063500  ...          79217
# 3                CK36            ACT     0.000000  ...           5106
# 4                CK42            ACT     0.000000  ...           4183
# ...               ...            ...          ...  ...            ...
# 89800            CK06            ACT     0.000300  ...          40467
# 89801            BTC2            ACT     0.000000  ...           1221
# 89802            BTC3            ACT     0.000000  ...           1221
# 89803            BTC1            ACT     0.000000  ...           1221
# 89804            CK12            ACT     0.000000  ...           1221
#
#        ownership_key address_key householdnbr       datelastmaint  Category  \
# 0            43261.0     44260.0     187340.0 2020-02-26 23:28:03       NaN
# 1            59661.0     61147.0     193906.0 2023-09-22 08:01:38       CRE
# 2            83546.0     85431.0     288455.0 2024-06-11 12:02:04       CRE
# 3            35118.0     35620.0          NaN                 NaT       NaN
# 4            33668.0     33967.0          NaN                 NaT       NaN
# ...              ...         ...          ...                 ...       ...
# 89800        41934.0     42975.0     112816.0 2020-02-26 23:27:59       NaN
# 89801         1352.0     41645.0     255924.0 2022-09-27 22:46:27       NaN
# 89802         1352.0     41577.0     255924.0 2022-09-27 22:46:27       NaN
# 89803         1352.0     41437.0     255924.0 2022-09-27 22:46:27       NaN
# 89804         1352.0     51094.0     255924.0 2022-09-27 22:46:27       NaN
#
#       inactivedate                      branchname  primaryownercity  \
# 0              NaT              BCSB - MAIN OFFICE       MINNEAPOLIS
# 1              NaT  BCSB - COMM'L LENDING- TAUNTON         BRAINTREE
# 2              NaT  BCSB - COMM'L LENDING- TAUNTON         WAKEFIELD
# 3              NaT    BCSB - MUNI ATTLEBORO BRANCH         ATTLEBORO
# 4              NaT         BCSB - MUNI MAIN OFFICE           TAUNTON
# ...            ...                             ...               ...
# 89800          NaT    BCSB - NB ASHLEY BLVD BRANCH       NEW BEDFORD
# 89801          NaT              BCSB - MAIN OFFICE           TAUNTON
# 89802          NaT              BCSB - MAIN OFFICE           TAUNTON
# 89803          NaT              BCSB - MAIN OFFICE           TAUNTON
# 89804          NaT       BCSB - DEPOSIT OPERATIONS           TAUNTON
#
#       primaryownerstate
# 0                    MN
# 1                    MA
# 2                    MA
# 3                    MA
# 4                    MA
# ...                 ...
# 89800                MA
# 89801                MA
# 89802                MA
# 89803                MA
# 89804                MA
#
# [89805 rows x 50 columns]

# %%
# OUTPUT_PATH = Path('acct_table.csv')
# df.to_csv(OUTPUT_PATH, index=False)

# %%
# import hashlib

# %%
# def mask_pii(data, columns_to_mask, length=10):
#     """
#     Create a masking layer

#     Pass in a dataframe to blackbox abstraction and get a dataframe returned with masked PII in specified fields

#     Parameters:
#     - data: raw data
#     - columns_to_mask: list of columns
#     - length: length of hash (10+ is recommended based on size of the data)
#     """
#     df_hashed = data.copy()

#     for col in columns_to_mask:
#         if col in df_hashed.columns:
#             df_hashed[col] = df_hashed[col].astype(str).apply(
#                 lambda x: hashlib.sha256(x.encode('utf-8')).hexdigest()[:length]
#             )
#         else:
#             raise ValueError(f"Column {col} not found in dataframe passed in")
        
#     return df_hashed

# %%
# columns_to_mask = [
#     'acctnbr',
#     'ownersortname',
#     'loanofficer',
#     'acctofficer',
#     'taxrptfororgnbr',
#     'taxrptforpersnbr'
#     ]

# masked_df = mask_pii(df, columns_to_mask)

# %%
# masked_df
# Out:
#          effdate     acctnbr ownersortname                       product  \
# 0     2025-06-30  a4844ced64    de652761d2             Treasurer's Check
# 1     2025-06-30  663a99673a    d3f38b27c9          Commercial Mortgages
# 2     2025-06-30  645c1385d8    1e1b34ee77          Commercial Mortgages
# 3     2025-06-30  8b1b9a6fa3    ac492580db    ICS Shadow - Muni - Demand
# 4     2025-06-30  f836255d08    b6bdb9d456  ICS Shadow - Muni - MMDA/SAV
# ...          ...         ...           ...                           ...
# 89800 2025-06-30  4a43dada63    a561e48737           Prime Time Checking
# 89801 2025-06-30  98fb6ce2ca    fb997c4e98               Payoff Overages
# 89802 2025-06-30  8b26fbd862    fb997c4e98      Escrow Checks Processing
# 89803 2025-06-30  b04fe631e2    fb997c4e98              PDO Checks - OLD
# 89804 2025-06-30  d347b5cf76    fb997c4e98             Business Checking
#
#        noteopenamt ratetypcd mjaccttypcd currmiaccttypcd curracctstatcd  \
# 0              0.0      None        BKCK            TRCK            ACT
# 1       65500000.0       VAR         CML            CM40            ACT
# 2       26000000.0       FIX         CML            CM40            ACT
# 3              0.0      None          CK            CK36            ACT
# 4              0.0      None          CK            CK42            ACT
# ...            ...       ...         ...             ...            ...
# 89800          0.0       VAR          CK            CK06            ACT
# 89801          0.0      None        BKCK            BTC2            ACT
# 89802          0.0      None        BKCK            BTC3            ACT
# 89803          0.0      None        BKCK            BTC1            ACT
# 89804          0.0      None          CK            CK12            ACT
#
#        noteintrate  ...  portfolio_key  ownership_key address_key  \
# 0         0.000000  ...          41516        43261.0     44260.0
# 1         0.065722  ...          57113        59661.0     61147.0
# 2         0.063500  ...          79217        83546.0     85431.0
# 3         0.000000  ...           5106        35118.0     35620.0
# 4         0.000000  ...           4183        33668.0     33967.0
# ...            ...  ...            ...            ...         ...
# 89800     0.000300  ...          40467        41934.0     42975.0
# 89801     0.000000  ...           1221         1352.0     41645.0
# 89802     0.000000  ...           1221         1352.0     41577.0
# 89803     0.000000  ...           1221         1352.0     41437.0
# 89804     0.000000  ...           1221         1352.0     51094.0
#
#       householdnbr       datelastmaint Category inactivedate  \
# 0         187340.0 2020-02-26 23:28:03      NaN          NaT
# 1         193906.0 2023-09-22 08:01:38      CRE          NaT
# 2         288455.0 2024-06-11 12:02:04      CRE          NaT
# 3              NaN                 NaT      NaN          NaT
# 4              NaN                 NaT      NaN          NaT
# ...            ...                 ...      ...          ...
# 89800     112816.0 2020-02-26 23:27:59      NaN          NaT
# 89801     255924.0 2022-09-27 22:46:27      NaN          NaT
# 89802     255924.0 2022-09-27 22:46:27      NaN          NaT
# 89803     255924.0 2022-09-27 22:46:27      NaN          NaT
# 89804     255924.0 2022-09-27 22:46:27      NaN          NaT
#
#                            branchname  primaryownercity primaryownerstate
# 0                  BCSB - MAIN OFFICE       MINNEAPOLIS                MN
# 1      BCSB - COMM'L LENDING- TAUNTON         BRAINTREE                MA
# 2      BCSB - COMM'L LENDING- TAUNTON         WAKEFIELD                MA
# 3        BCSB - MUNI ATTLEBORO BRANCH         ATTLEBORO                MA
# 4             BCSB - MUNI MAIN OFFICE           TAUNTON                MA
# ...                               ...               ...               ...
# 89800    BCSB - NB ASHLEY BLVD BRANCH       NEW BEDFORD                MA
# 89801              BCSB - MAIN OFFICE           TAUNTON                MA
# 89802              BCSB - MAIN OFFICE           TAUNTON                MA
# 89803              BCSB - MAIN OFFICE           TAUNTON                MA
# 89804       BCSB - DEPOSIT OPERATIONS           TAUNTON                MA
#
# [89805 rows x 50 columns]

# %%
# transposed_df = masked_df.head(3).T.reset_index()

# %%
# transposed_df
# Out:
#                      index                    0  \
# 0                  effdate  2025-06-30 00:00:00
# 1                  acctnbr           a4844ced64
# 2            ownersortname           de652761d2
# 3                  product    Treasurer's Check
# 4              noteopenamt                  0.0
# 5                ratetypcd                 None
# 6              mjaccttypcd                 BKCK
# 7          currmiaccttypcd                 TRCK
# 8           curracctstatcd                  ACT
# 9              noteintrate                  0.0
# 10             bookbalance        1594158229.35
# 11                 notebal        1594158229.35
# 12            contractdate  2018-08-03 00:00:00
# 13                 datemat                  NaT
# 14         taxrptfororgnbr           102ef424ea
# 15        taxrptforpersnbr           9b2d5b4678
# 16             loanofficer           dc937b5989
# 17             acctofficer           dc937b5989
# 18          creditlimitamt                  0.0
# 19             origintrate                  NaN
# 20             marginfixed                  NaN
# 21               fdiccatcd                  NaN
# 22               amortterm                  NaN
# 23            totalpctsold                  0.0
# 24                   cobal                  0.0
# 25     credlimitclatresamt                  0.0
# 26            riskratingcd                  NaN
# 27                origdate                  NaT
# 28                currterm                  NaN
# 29                 loanidx                  NaN
# 30                     rcf                  NaN
# 31             availbalamt                  0.0
# 32             fdiccatdesc                  NaN
# 33                 origbal                  NaN
# 34             loanlimityn                  NaN
# 35             Net Balance        1594158229.35
# 36           Net Available                  0.0
# 37  Net Collateral Reserve                  0.0
# 38          Total Exposure        1594158229.35
# 39       orig_ttl_loan_amt                  0.0
# 40           portfolio_key                41516
# 41           ownership_key              43261.0
# 42             address_key              44260.0
# 43            householdnbr             187340.0
# 44           datelastmaint  2020-02-26 23:28:03
# 45                Category                  NaN
# 46            inactivedate                  NaT
# 47              branchname   BCSB - MAIN OFFICE
# 48        primaryownercity          MINNEAPOLIS
# 49       primaryownerstate                   MN
#
#                                  1                               2
# 0              2025-06-30 00:00:00             2025-06-30 00:00:00
# 1                       663a99673a                      645c1385d8
# 2                       d3f38b27c9                      1e1b34ee77
# 3             Commercial Mortgages            Commercial Mortgages
# 4                       65500000.0                      26000000.0
# 5                              VAR                             FIX
# 6                              CML                             CML
# 7                             CM40                            CM40
# 8                              ACT                             ACT
# 9                         0.065722                          0.0635
# 10                      29000000.0                      26000000.0
# 11                      65500000.0                      26000000.0
# 12             2023-09-12 00:00:00             2024-06-05 00:00:00
# 13             2028-08-01 00:00:00             2029-06-05 00:00:00
# 14                      bcdc61432c                      f765fe3302
# 15                      9b2d5b4678                      9b2d5b4678
# 16                      a9aa507ce8                      cbb324b28b
# 17                      dc937b5989                      dc937b5989
# 18                             0.0                             0.0
# 19                         0.07584                          0.0635
# 20                          0.0225                               0
# 21                            REMU                            RENO
# 22                         10950.0                         10950.0
# 23                        0.557252                             0.0
# 24                             0.0                             0.0
# 25                             0.0                             0.0
# 26                              3C                              3M
# 27             2023-09-13 10:22:16             2024-06-10 11:53:26
# 28                            59.0                            60.0
# 29           1 Month CME Term SOFR                the Loan Default
# 30                            MNTH                            None
# 31                             0.0                             0.0
# 32                  RE/Multifamily   NonOwnOcc/RE/Non-Farm/Non-Res
# 33                      65500000.0                      26000000.0
# 34                               N                               N
# 35                      29000000.0                      26000000.0
# 36                             0.0                             0.0
# 37                             0.0                             0.0
# 38                      29000000.0                      26000000.0
# 39                      65500000.0                      26000000.0
# 40                           57113                           79217
# 41                         59661.0                         83546.0
# 42                         61147.0                         85431.0
# 43                        193906.0                        288455.0
# 44             2023-09-22 08:01:38             2024-06-11 12:02:04
# 45                             CRE                             CRE
# 46                             NaT                             NaT
# 47  BCSB - COMM'L LENDING- TAUNTON  BCSB - COMM'L LENDING- TAUNTON
# 48                       BRAINTREE                       WAKEFIELD
# 49                              MA                              MA

# %%
# OUTPUT_PATH = Path('masked_acct_table.csv')
# masked_df.to_csv(OUTPUT_PATH, index=False)
