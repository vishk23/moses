# %%
# %%
## Memorializing this as the easy way to lookup accounts


# %%
"""
Main Entry Point
"""
from pathlib import Path
from typing import List
import argparse
from datetime import datetime

import pandas as pd # type: ignore

import src.additional_fields
import src.fetch_data # type: ignore
import src.core_transform # type: ignore
import cdutils.pkey_sqlite # type: ignore
import cdutils.hhnbr # type: ignore
import cdutils.loans.calculations
import cdutils.inactive_date
import cdutils.input_cleansing

# Current (doesn't really work without)
# data = src.fetch_data.fetch_data()


# # Specific date
# specified_date = datetime(2020, 12, 31)

def query_df_on_date(specified_date):

    data = src.fetch_data.fetch_data(specified_date)

    # # # Core transformation pipeline
    raw_data = src.core_transform.main_pipeline(data)

    # Raw data with pkey appended
    raw_data = cdutils.pkey_sqlite.add_pkey(raw_data)
    raw_data = cdutils.pkey_sqlite.add_ownership_key(raw_data)
    raw_data = cdutils.pkey_sqlite.add_address_key(raw_data)

    # %%
    househldacct = data['househldacct'].copy()
    raw_data = cdutils.hhnbr.add_hh_nbr(raw_data, househldacct)

    # %%
    raw_data

    # %%

    # %%
    loan_category_df = cdutils.loans.calculations.categorize_loans(raw_data)

    # %%
    loan_category_df = loan_category_df[['acctnbr','Category']].copy()

    # %%
    df = pd.merge(raw_data, loan_category_df, on='acctnbr', how='left')

    # %%
    df

    # %%

    df = cdutils.inactive_date.append_inactive_date(df)

    # %%
    df

    # %%
    pers = data['wh_pers'].copy()

    # %%
    # df.info()

    # %%

    additional_fields = src.additional_fields.fetch_data(specified_date)

    # %%
    additional_fields_to_append = additional_fields['wh_acctcommon'].copy()

    # %%

    additional_fields_to_append_schema = {
        'acctnbr':'str'
    }

    additional_fields_to_append = cdutils.input_cleansing.enforce_schema(additional_fields_to_append, additional_fields_to_append_schema)

    # %%
    df = pd.merge(df, additional_fields_to_append, how='left', on='acctnbr')

    # %%
    return df

# %%
# OUTPUT_PATH = Path('acct_table.csv')
# df.to_csv(OUTPUT_PATH, index=False)

# %%
# import hashlib

# %%
# def mask_pii(data, columns_to_mask, length=10):
#     """
#     Create a masking layer

#     Pass in a dataframe to blackbox abstraction and get a dataframe returned with masked PII in specified fields

#     Parameters:
#     - data: raw data
#     - columns_to_mask: list of columns
#     - length: length of hash (10+ is recommended based on size of the data)
#     """
#     df_hashed = data.copy()

#     for col in columns_to_mask:
#         if col in df_hashed.columns:
#             df_hashed[col] = df_hashed[col].astype(str).apply(
#                 lambda x: hashlib.sha256(x.encode('utf-8')).hexdigest()[:length]
#             )
#         else:
#             raise ValueError(f"Column {col} not found in dataframe passed in")
        
#     return df_hashed

# %%
# columns_to_mask = [
#     'acctnbr',
#     'ownersortname',
#     'loanofficer',
#     'acctofficer',
#     'taxrptfororgnbr',
#     'taxrptforpersnbr'
#     ]

# masked_df = mask_pii(df, columns_to_mask)

# %%
# masked_df

# %%
# transposed_df = masked_df.head(3).T.reset_index()

# %%
# transposed_df

# %%
# OUTPUT_PATH = Path('masked_acct_table.csv')
# masked_df.to_csv(OUTPUT_PATH, index=False)

# %%

# %%
"""
Data cleaning main pipeline for Accubranch project.

This module implements the high-level data pipeline workflow:
1. Generate/load the acct_df (account data)
2. Merge with organization data and exclude Municipal & Fiduciary accounts
3. Merge with person data to get DOB (join on taxrptforpersnbr)
4. Append address data through orgaddruse/persaddruse tables to get address details

The result is a comprehensive dataframe that serves as the backbone for:
- Account Section reporting (as of any date)
- Annual deposit analysis

Data sources are modular and can be easily swapped between mock data and production database.
"""

import pandas as pd
from datetime import datetime
from pathlib import Path
from typing import Optional, Dict, Any

from src.join_functions import (
    join_accounts_with_orgs,
    join_accounts_with_persons,
    join_accounts_with_addresses
)
import src.acct_data_gathering


def load_mock_data() -> Dict[str, pd.DataFrame]:
    """
    Load data from mock CSV files.
    
    Returns:
    --------
    dict
        Dictionary containing all required dataframes for the pipeline
    """
    base_path = Path("assets/mock_data")
    
    return {
        'wh_org': pd.read_csv(base_path / "wh_org.csv"),
        'wh_pers': pd.read_csv(base_path / "wh_pers.csv"),
        'wh_addr': pd.read_csv(base_path / "wh_addr.csv"),
        'orgaddruse': pd.read_csv(base_path / "orgaddruse.csv"),
        'persaddruse': pd.read_csv(base_path / "persaddruse.csv")
    }


def load_production_data() -> Dict[str, pd.DataFrame]:
    """
    Load data from production database.
    
    This is a placeholder function that would be implemented to connect
    to the actual production database and retrieve the required tables.
    
    Returns:
    --------
    dict
        Dictionary containing all required dataframes for the pipeline
    """

    data = src.acct_data_gathering.fetch_data()
    return data
    
def run_data_cleaning_pipeline(
    as_of_date: datetime,
    data_source: str = "mock",
    exclude_org_types: Optional[list] = None,
    address_use_type: str = "PRI"
) -> pd.DataFrame:
    """
    Run the complete data cleaning pipeline following the workflow:
    1. Generate account data for specified date
    2. Merge with organizations (excluding Municipal & Fiduciary)
    3. Merge with persons to get DOB
    4. Append address information
    
    Parameters:
    -----------
    as_of_date : datetime
        The date for which to generate account data
    data_source : str, default "mock"
        Data source to use ("mock" or "production")
    exclude_org_types : list, optional
        Organization types to exclude (defaults to Municipal & Fiduciary)
    address_use_type : str, default "PRI"
        Address use type to filter for (e.g., 'PRI' for primary addresses)
        
    Returns:
    --------
    pd.DataFrame
        Comprehensive dataframe with account, customer, and address data
        
    Example:
    --------
    >>> from datetime import datetime
    >>> result = run_data_cleaning_pipeline(
    ...     as_of_date=datetime(2024, 12, 31),
    ...     data_source="mock",
    ...     exclude_org_types=['MUNIC', 'FIDUC']
    ... )
    >>> print(f"Final dataset: {len(result)} accounts with {len(result.columns)} columns")
    """
    
    # Set default exclusions for Municipal & Fiduciary accounts
    if exclude_org_types is None:
        exclude_org_types = ['MUNIC', 'FIDUC']  # Municipal & Fiduciary Accounts
    
    print(f"Starting data cleaning pipeline for {as_of_date.date()}")
    print(f"Using data source: {data_source}")
    print(f"Excluding organization types: {exclude_org_types}")
    
    # Step 1: Load supporting data based on source
    print("\n=== Step 1: Loading supporting data ===")
    if data_source == "mock":
        data_tables = load_mock_data()
        print("Loaded mock data from CSV files")
    elif data_source == "production":
        data_tables = load_production_data()
        print("Loaded production data from database")
    else:
        raise ValueError(f"Unknown data source: {data_source}. Use 'mock' or 'production'")
    
    # Step 2: Generate account data for the specified date
    print(f"\n=== Step 2: Generating account data for {as_of_date.date()} ===")
    acct_df = query_df_on_date(as_of_date)
    print(f"Generated {len(acct_df)} account records")
    print(f"Account types: {acct_df['mjaccttypcd'].value_counts().to_dict()}")
    
    # Step 3: Merge with organizations and exclude specified types
    print(f"\n=== Step 3: Merging with organizations (excluding {exclude_org_types}) ===")
    org_merged_df = join_accounts_with_orgs(
        acct_df, 
        data_tables['wh_org'], 
        exclude_org_types=exclude_org_types
    )
    print(f"After organization merge and filtering: {len(org_merged_df)} accounts")
    
    # Step 4: Merge with persons to get DOB (join on taxrptforpersnbr)
    print(f"\n=== Step 4: Merging with persons to append DOB ===")
    pers_merged_df = join_accounts_with_persons(org_merged_df, data_tables['wh_pers'])
    person_accounts = pers_merged_df['datebirth'].notna().sum()
    print(f"After person merge: {len(pers_merged_df)} accounts ({person_accounts} with person data)")
    
    # Step 5: Append address information
    print(f"\n=== Step 5: Appending address information ===")
    
    # Split accounts by customer type for address joins
    org_accounts = pers_merged_df[pers_merged_df['taxrptfororgnbr'].notna()]
    person_accounts = pers_merged_df[pers_merged_df['taxrptforpersnbr'].notna()]
    other_accounts = pers_merged_df[
        pers_merged_df['taxrptfororgnbr'].isna() & pers_merged_df['taxrptforpersnbr'].isna()
    ]
    
    print(f"Organization accounts: {len(org_accounts)}")
    print(f"Person accounts: {len(person_accounts)}")
    print(f"Other accounts (no customer link): {len(other_accounts)}")
    
    # Join organization addresses
    if len(org_accounts) > 0:
        org_with_addr = join_accounts_with_addresses(
            org_accounts, 
            data_tables['orgaddruse'], 
            data_tables['wh_addr'], 
            address_use_type=address_use_type
        )
        org_addr_count = org_with_addr['text1'].notna().sum()
        print(f"Organization accounts with addresses: {org_addr_count}/{len(org_accounts)}")
    else:
        org_with_addr = pd.DataFrame()
    
    # Join person addresses
    if len(person_accounts) > 0:
        pers_with_addr = join_accounts_with_addresses(
            person_accounts, 
            data_tables['persaddruse'], 
            data_tables['wh_addr'], 
            address_use_type=address_use_type
        )
        pers_addr_count = pers_with_addr['text1'].notna().sum()
        print(f"Person accounts with addresses: {pers_addr_count}/{len(person_accounts)}")
    else:
        pers_with_addr = pd.DataFrame()
    
    # Combine all results
    dataframes_to_combine = []
    if len(org_with_addr) > 0:
        dataframes_to_combine.append(org_with_addr)
    if len(pers_with_addr) > 0:
        dataframes_to_combine.append(pers_with_addr)
    if len(other_accounts) > 0:
        # Add empty address columns to other_accounts to match schema
        address_cols = ['text1', 'text2', 'text3', 'cityname', 'statecd', 'zipcd', 'addrnbr']
        for col in address_cols:
            if col not in other_accounts.columns:
                other_accounts[col] = pd.NA
        dataframes_to_combine.append(other_accounts)
    
    if dataframes_to_combine:
        final_df = pd.concat(dataframes_to_combine, ignore_index=True)
    else:
        final_df = pers_merged_df  # Fallback if no addresses found
    
    # Step 6: Final summary
    print(f"\n=== Pipeline Complete ===")
    print(f"Final dataset: {len(final_df)} accounts with {len(final_df.columns)} columns")
    total_with_addresses = final_df['text1'].notna().sum()
    print(f"Accounts with address data: {total_with_addresses}/{len(final_df)} ({total_with_addresses/len(final_df)*100:.1f}%)")
    
    # Summary by account type
    print(f"\nAccount type summary:")
    for acct_type, count in final_df['mjaccttypcd'].value_counts().items():
        print(f"  {acct_type}: {count}")
    
    return final_df

# %%
data = load_production_data()

# %%
data.keys()
# Out:
# dict_keys(['wh_addr', 'orgaddruse', 'persaddruse', 'wh_org', 'wh_pers'])

# %%
org = data['wh_org'].copy()

# %%
org.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17096 entries, 0 to 17095
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   orgnbr         17096 non-null  int64
#  1   orgname        17096 non-null  object
#  2   orgtypcd       16921 non-null  object
#  3   orgtypcddesc   16921 non-null  object
#  4   taxid          13358 non-null  object
#  5   taxidtypcd     13509 non-null  object
#  6   rpt1099intyn   17096 non-null  object
#  7   privacyyn      17096 non-null  object
#  8   taxexemptyn    17096 non-null  object
#  9   cipratingcd    67 non-null     object
#  10  creditscore    1644 non-null   float64
#  11  siccd          331 non-null    object
#  12  siccddesc      331 non-null    object
#  13  sicsubcd       311 non-null    object
#  14  sicsubcddesc   308 non-null    object
#  15  naicscd        11407 non-null  object
#  16  naicscddesc    11407 non-null  object
#  17  adddate        17096 non-null  datetime64[ns]
#  18  datelastmaint  17096 non-null  datetime64[ns]
#  19  rundate        17096 non-null  datetime64[ns]
#  20  allowpromoyn   17096 non-null  object
#  21  homeemail      2385 non-null   object
#  22  busemail       5054 non-null   object
# dtypes: datetime64[ns](3), float64(1), int64(1), object(18)
# memory usage: 3.0+ MB

# %%
org
# Out:
#         orgnbr                                   orgname orgtypcd  \
# 0      1003030            CORNELL MILL MASTER TENANT LLC      LLC
# 1      1003031  KOSTKAS TAUNTON HARDWARE & SUPPLY CO INC     CORP
# 2      1003032                                  AAFR INC     CORP
# 3      1003033                      161 POPES ISLAND LLC      LLC
# 4      1003034                       PETER TETREAULT INC     CORP
# ...        ...                                       ...      ...
# 17091  1013981                      CALVERT FAMILY TRUST     TRST
# 17092  1013996                JOHNSON TRANSPORTATION LLC      LLC
# 17093  1014008                COMMERCIAL CARPET CLEANING      DBA
# 17094  1014035          FRANKLIN ANALYTICAL SERVICES INC     CORP
# 17095  1014040              MEDEIROS FAMILY LIVING TRUST     TRST
#
#                         orgtypcddesc                             taxid  \
# 0      Limited Liability Corporation  D659FFA35580DFB3D1899D0595A33C2B
# 1               Corporation/Business  E3E23BF51CA86F99980ECCCDA46AF261
# 2               Corporation/Business  E70F9A4AC91DAB6C466E922309E61BF7
# 3      Limited Liability Corporation  C477A5C4B1CEFE125DA660E6EF62B149
# 4               Corporation/Business  ED849F76A707CFB27C30FE65BB8423B5
# ...                              ...                               ...
# 17091                Trust/Fiduciary                              None
# 17092  Limited Liability Corporation  90AEFF56BD47D77EC5D22796A2203FA9
# 17093              Doing Business As  EAA9EF160AAE4AEC77E80FDA017B2DD8
# 17094           Corporation/Business  4705F64CD0336DA1DFFFC97359C5498D
# 17095                Trust/Fiduciary                              None
#
#       taxidtypcd rpt1099intyn privacyyn taxexemptyn cipratingcd  ...  \
# 0           FEIN            Y         N           N        None  ...
# 1           FEIN            Y         N           N        None  ...
# 2           FEIN            Y         N           N        None  ...
# 3           FEIN            Y         N           N        None  ...
# 4           FEIN            Y         N           N        None  ...
# ...          ...          ...       ...         ...         ...  ...
# 17091       None            Y         N           N        None  ...
# 17092       FEIN            Y         N           N        None  ...
# 17093       FEIN            Y         N           N        None  ...
# 17094       FEIN            Y         N           N        None  ...
# 17095       None            Y         N           N        None  ...
#
#        sicsubcd                         sicsubcddesc naicscd  \
# 0          None                                 None  531311
# 1          None                                 None  444130
# 2          None                                 None  813990
# 3          None                                 None  813990
# 4          None                                 None    None
# ...         ...                                  ...     ...
# 17091      None                                 None  525920
# 17092      4212  4212-Local Trucking Without Storage  484110
# 17093      None                                 None  811490
# 17094      None                                 None  238990
# 17095      None                                 None    None
#
#                                              naicscddesc    adddate  \
# 0                          Residential Property Managers 2016-08-08
# 1                                        Hardware Stores 1993-10-01
# 2      Other Similar Organizations (except Business, ... 2017-01-20
# 3      Other Similar Organizations (except Business, ... 2017-06-01
# 4                                                   None 1994-04-29
# ...                                                  ...        ...
# 17091               Trusts, Estates, and Agency Accounts 2022-04-08
# 17092                    General Freight Trucking, Local 2022-04-14
# 17093  Other Personal and Household Goods Repair and ... 2022-04-15
# 17094              All Other Specialty Trade Contractors 2022-04-20
# 17095                                               None 2022-04-21
#
#             datelastmaint    rundate allowpromoyn  \
# 0     2025-07-15 21:27:18 2025-07-15            N
# 1     2025-07-15 21:27:18 2025-07-15            N
# 2     2025-07-15 21:27:18 2025-07-15            N
# 3     2025-07-15 21:27:18 2025-07-15            N
# 4     2025-07-15 21:27:18 2025-07-15            N
# ...                   ...        ...          ...
# 17091 2025-07-15 21:27:19 2025-07-15            N
# 17092 2025-07-15 21:27:19 2025-07-15            N
# 17093 2025-07-15 21:27:19 2025-07-15            N
# 17094 2025-07-15 21:27:19 2025-07-15            N
# 17095 2025-07-15 21:27:19 2025-07-15            N
#
#                            homeemail                          busemail
# 0                cstarr@starrdev.com                              None
# 1                               None                              None
# 2      academicarestaurant@gmail.com             afern1961@verizon.net
# 3                               None                              None
# 4              mirimichi@comcast.net                              None
# ...                              ...                               ...
# 17091                           None          calvert.karene@gmail.com
# 17092      nickjohnson7647@gmail.com         nickjohnson7647@gmail.com
# 17093                           None        etruscanbeast822@gmail.com
# 17094                           None  afranklin@franklinanalytical.net
# 17095                           None                              None
#
# [17096 rows x 23 columns]

# %%
data2020 = run_data_cleaning_pipeline(
    as_of_date=datetime(2020, 12, 31),
    data_source="production",
    exclude_org_types=["MUNI","TRST"]
)

data2021 = run_data_cleaning_pipeline(
    as_of_date=datetime(2021, 12, 31),
    data_source="production",
    exclude_org_types=["MUNI","TRST"]
)

data2022 = run_data_cleaning_pipeline(
    as_of_date=datetime(2022, 12, 30),
    data_source="production",
    exclude_org_types=["MUNI","TRST"]
)

data2023 = run_data_cleaning_pipeline(
    as_of_date=datetime(2023, 12, 29),
    data_source="production",
    exclude_org_types=["MUNI","TRST"]
)

data2024 = run_data_cleaning_pipeline(
    as_of_date=datetime(2024, 12, 31),
    data_source="production",
    exclude_org_types=["MUNI","TRST"]
)
# Out:
# Starting data cleaning pipeline for 2020-12-31
# Using data source: production
# Excluding organization types: ['MUNI', 'TRST']
#
# === Step 1: Loading supporting data ===
# Loaded production data from database
#
# === Step 2: Generating account data for 2020-12-31 ===
# Generated 91019 account records
# Account types: {'CK': 34663, 'CNS': 20004, 'SAV': 17560, 'TD': 7194, 'MTG': 3815, 'CML': 3783, 'RTMT': 2018, 'LEAS': 1964, 'BKCK': 12, 'MLN': 6}
#
# === Step 3: Merging with organizations (excluding ['MUNI', 'TRST']) ===
# Excluded 1455 records with organization types: ['MUNI', 'TRST']
# After organization merge and filtering: 89564 accounts
#
# === Step 4: Merging with persons to append DOB ===
# After person merge: 89564 accounts (78217 with person data)
#
# === Step 5: Appending address information ===
# Organization accounts: 11134
# Person accounts: 78430
# Other accounts (no customer link): 0
# Organization accounts with addresses: 11129/11134
# Person accounts with addresses: 78424/78430
#
# === Pipeline Complete ===
# Final dataset: 89564 accounts with 108 columns
# Accounts with address data: 89553/89564 (100.0%)
#
# Account type summary:
#   CK: 33514
#   CNS: 20004
#   SAV: 17520
#   TD: 7053
#   MTG: 3815
#   CML: 3659
#   RTMT: 2017
#   LEAS: 1964
#   BKCK: 12
#   MLN: 6
# Starting data cleaning pipeline for 2021-12-31
# Using data source: production
# Excluding organization types: ['MUNI', 'TRST']
#
# === Step 1: Loading supporting data ===
# Loaded production data from database
#
# === Step 2: Generating account data for 2021-12-31 ===
# Generated 88944 account records
# Account types: {'CK': 35124, 'CNS': 19354, 'SAV': 17263, 'TD': 6555, 'MTG': 3894, 'CML': 2837, 'LEAS': 1978, 'RTMT': 1921, 'BKCK': 12, 'MLN': 6}
#
# === Step 3: Merging with organizations (excluding ['MUNI', 'TRST']) ===
# Excluded 1470 records with organization types: ['MUNI', 'TRST']
# After organization merge and filtering: 87474 accounts
#
# === Step 4: Merging with persons to append DOB ===
# After person merge: 87474 accounts (77069 with person data)
#
# === Step 5: Appending address information ===
# Organization accounts: 10235
# Person accounts: 77239
# Other accounts (no customer link): 0
# Organization accounts with addresses: 10224/10235
# Person accounts with addresses: 77230/77239
#
# === Pipeline Complete ===
# Final dataset: 87474 accounts with 108 columns
# Accounts with address data: 87454/87474 (100.0%)
#
# Account type summary:
#   CK: 33974
#   CNS: 19354
#   SAV: 17220
#   TD: 6413
#   MTG: 3894
#   CML: 2702
#   LEAS: 1978
#   RTMT: 1921
#   BKCK: 12
#   MLN: 6
# Starting data cleaning pipeline for 2022-12-30
# Using data source: production
# Excluding organization types: ['MUNI', 'TRST']
#
# === Step 1: Loading supporting data ===
# Loaded production data from database
#
# === Step 2: Generating account data for 2022-12-30 ===
# Generated 88835 account records
# Account types: {'CK': 35426, 'CNS': 19858, 'SAV': 16792, 'TD': 6241, 'MTG': 4088, 'CML': 2680, 'LEAS': 1908, 'RTMT': 1825, 'BKCK': 12, 'MLN': 5}
#
# === Step 3: Merging with organizations (excluding ['MUNI', 'TRST']) ===
# Excluded 1593 records with organization types: ['MUNI', 'TRST']
# After organization merge and filtering: 87242 accounts
#
# === Step 4: Merging with persons to append DOB ===
# After person merge: 87242 accounts (76934 with person data)
#
# === Step 5: Appending address information ===
# Organization accounts: 10140
# Person accounts: 77102
# Other accounts (no customer link): 0
# Organization accounts with addresses: 10122/10140
# Person accounts with addresses: 77094/77102
#
# === Pipeline Complete ===
# Final dataset: 87242 accounts with 108 columns
# Accounts with address data: 87216/87242 (100.0%)
#
# Account type summary:
#   CK: 34151
#   CNS: 19858
#   SAV: 16752
#   TD: 6108
#   MTG: 4088
#   CML: 2535
#   LEAS: 1908
#   RTMT: 1825
#   BKCK: 12
#   MLN: 5
# Starting data cleaning pipeline for 2023-12-29
# Using data source: production
# Excluding organization types: ['MUNI', 'TRST']
#
# === Step 1: Loading supporting data ===
# Loaded production data from database
#
# === Step 2: Generating account data for 2023-12-29 ===
# Generated 90750 account records
# Account types: {'CK': 35956, 'CNS': 19250, 'SAV': 16313, 'TD': 8648, 'MTG': 4261, 'CML': 2644, 'LEAS': 1889, 'RTMT': 1772, 'BKCK': 12, 'MLN': 5}
#
# === Step 3: Merging with organizations (excluding ['MUNI', 'TRST']) ===
# Excluded 1632 records with organization types: ['MUNI', 'TRST']
# After organization merge and filtering: 89118 accounts
#
# === Step 4: Merging with persons to append DOB ===
# After person merge: 89118 accounts (78696 with person data)
#
# === Step 5: Appending address information ===
# Organization accounts: 10274
# Person accounts: 78844
# Other accounts (no customer link): 0
# Organization accounts with addresses: 10257/10274
# Person accounts with addresses: 78837/78844
#
# === Pipeline Complete ===
# Final dataset: 89118 accounts with 108 columns
# Accounts with address data: 89094/89118 (100.0%)
#
# Account type summary:
#   CK: 34684
#   CNS: 19250
#   SAV: 16273
#   TD: 8477
#   MTG: 4261
#   CML: 2497
#   LEAS: 1889
#   RTMT: 1770
#   BKCK: 12
#   MLN: 5
# Starting data cleaning pipeline for 2024-12-31
# Using data source: production
# Excluding organization types: ['MUNI', 'TRST']
#
# === Step 1: Loading supporting data ===
# Loaded production data from database
#
# === Step 2: Generating account data for 2024-12-31 ===
# Generated 90812 account records
# Account types: {'CK': 36805, 'CNS': 16749, 'SAV': 16271, 'TD': 9762, 'MTG': 4375, 'CML': 3305, 'LEAS': 1817, 'RTMT': 1712, 'BKCK': 12, 'MLN': 4}
#
# === Step 3: Merging with organizations (excluding ['MUNI', 'TRST']) ===
# Excluded 1798 records with organization types: ['MUNI', 'TRST']
# After organization merge and filtering: 89014 accounts
#
# === Step 4: Merging with persons to append DOB ===
# After person merge: 89014 accounts (78545 with person data)
#
# === Step 5: Appending address information ===
# Organization accounts: 10328
# Person accounts: 78686
# Other accounts (no customer link): 0
# Organization accounts with addresses: 10311/10328
# Person accounts with addresses: 78679/78686
#
# === Pipeline Complete ===
# Final dataset: 89014 accounts with 108 columns
# Accounts with address data: 88990/89014 (100.0%)
#
# Account type summary:
#   CK: 35377
#   CNS: 16749
#   SAV: 16225
#   TD: 9571
#   MTG: 4375
#   CML: 3173
#   LEAS: 1817
#   RTMT: 1711
#   BKCK: 12
#   MLN: 4

# %%
import src.annual_deposit_history


dataframes = [data2020, data2021, data2022, data2023, data2024]
dates = ['2020-12-31', '2021-12-31', '2022-12-31', '2023-12-31','2024-12-31']
five_yr_history = src.annual_deposit_history.create_time_series_analysis(dataframes, dates)
# Out:
# Creating time series analysis for 5 periods
# Processing period 1/5: 2020-12-31
#   - Found 32 branches
# Processing period 2/5: 2021-12-31
#   - Found 31 branches
# Processing period 3/5: 2022-12-31
#   - Found 30 branches
# Processing period 4/5: 2023-12-31
#   - Found 30 branches
# Processing period 5/5: 2024-12-31
#   - Found 28 branches
#
# Time series analysis complete:
# - 32 branches analyzed
# - 5 time periods

# %%
five_yr_history
# Out:
#                                      2020-12-31    2021-12-31    2022-12-31  \
# branchname
# BCSB - MAIN OFFICE                 2.754074e+08  2.671387e+08  2.502994e+08
# BCSB - ATTLEBORO BRANCH            2.251015e+08  2.467036e+08  2.201227e+08
# BCSB - NO ATTLEBORO BRANCH         1.821693e+08  2.364174e+08  1.889480e+08
# BCSB - RAYNHAM CENTER BRANCH       1.632555e+08  1.710617e+08  1.894111e+08
# BCSB - REHOBOTH BRANCH             1.332619e+08  1.554213e+08  1.619539e+08
# BCSB - PAWTUCKET BRANCH            1.259627e+08  1.388975e+08  1.492465e+08
# BCSB - COUNTY STREET BRANCH        9.080247e+07  1.022122e+08  1.040402e+08
# BCSB - DARTMOUTH BRANCH            1.031703e+08  1.129411e+08  1.096691e+08
# BCSB - NORTH RAYNHAM BRANCH        1.198817e+08  1.244201e+08  1.234095e+08
# BCSB - NB ASHLEY BLVD BRANCH       6.240310e+07  7.164436e+07  9.496153e+07
# BCSB - CANDLEWORKS BRANCH          3.053180e+07  7.114269e+07  6.999382e+07
# BCSB - EAST FREETOWN BRANCH        3.386432e+07  4.146732e+07  4.755865e+07
# BCSB - FALL RIVER BRANCH           5.450023e+07  6.895917e+07  5.525055e+07
# BCSB - GREENVILLE                  4.862586e+07  6.201857e+07  4.874658e+07
# BCSB - CUMBERLAND                  4.344918e+07  3.912548e+07  3.533710e+07
# BCSB - FRANKLIN BRANCH             3.499732e+07  4.210908e+07  4.256289e+07
# BCSB - DEPOSIT OPERATIONS          9.547377e+04  9.535945e+05  4.229442e+05
# BCSB - TAUNTON HIGH SCHOOL         3.180596e+06  3.471399e+06  3.587704e+06
# BCSB - MUNI DARTMOUTH BRANCH       8.315855e+05  1.198925e+06  1.795200e+06
# BCSB - MUNI CANDLEWORKS BRANCH     5.477447e+05  9.691603e+04  1.046934e+05
# BCSB - MUNI RAYNHAM CENTER BRANCH  1.278270e+06  1.422112e+06  1.461657e+06
# BCSB - MUNI MAIN OFFICE            1.788479e+06  1.930270e+06  1.254415e+06
# BCSB - MUNI NB ASHLEY BLVD BRANCH  3.878970e+03  3.388669e+04  4.323630e+05
# BCSB - MUNI REHOBOTH BRANCH        2.009485e+05  2.821657e+05  2.678105e+05
# BCSB - ATTLEBORO HIGH SCHOOL       2.967913e+05  3.953000e+05  4.644358e+05
# BCSB - CONTACT CENTER              1.286719e+07  1.791960e+07  1.263172e+07
# BCSB - MUNI EAST FREETOWN BRANCH   2.212932e+05  1.824197e+05  1.679531e+05
# BCSB - MUNI NORTH RAYNHAM BRANCH   5.760020e+05  7.542210e+05  3.684205e+05
# BCSB - MUNI COUNTY STREET BRANCH   1.059800e+05  1.060118e+05  5.501410e+03
# BCSB - MUNI FRANKLIN BRANCH        5.039386e+05  6.863464e+05  2.911751e+05
# BCSB - NB ROCKDALE AVE BRANCH      3.510350e+07  0.000000e+00  0.000000e+00
# BCSB - WALMART BRANCH              1.702878e+07  1.837922e+07  0.000000e+00
#
#                                      2023-12-31    2024-12-31
# branchname
# BCSB - MAIN OFFICE                 2.529378e+08  2.858495e+08
# BCSB - ATTLEBORO BRANCH            2.063590e+08  2.135514e+08
# BCSB - NO ATTLEBORO BRANCH         1.703292e+08  1.868927e+08
# BCSB - RAYNHAM CENTER BRANCH       1.783260e+08  1.856692e+08
# BCSB - REHOBOTH BRANCH             1.776106e+08  1.737061e+08
# BCSB - PAWTUCKET BRANCH            1.243418e+08  1.407033e+08
# BCSB - COUNTY STREET BRANCH        1.166127e+08  1.270184e+08
# BCSB - DARTMOUTH BRANCH            1.109043e+08  1.257360e+08
# BCSB - NORTH RAYNHAM BRANCH        1.140251e+08  1.142158e+08
# BCSB - NB ASHLEY BLVD BRANCH       9.384491e+07  8.307753e+07
# BCSB - CANDLEWORKS BRANCH          6.499789e+07  7.580113e+07
# BCSB - EAST FREETOWN BRANCH        5.800804e+07  6.506532e+07
# BCSB - FALL RIVER BRANCH           6.345678e+07  5.554802e+07
# BCSB - GREENVILLE                  4.421643e+07  4.002566e+07
# BCSB - CUMBERLAND                  3.639132e+07  3.302844e+07
# BCSB - FRANKLIN BRANCH             4.313778e+07  2.397238e+07
# BCSB - DEPOSIT OPERATIONS          5.021625e+07  1.019527e+07
# BCSB - TAUNTON HIGH SCHOOL         3.508807e+06  3.228966e+06
# BCSB - MUNI DARTMOUTH BRANCH       1.934456e+06  1.635015e+06
# BCSB - MUNI CANDLEWORKS BRANCH     1.412124e+06  1.406248e+06
# BCSB - MUNI RAYNHAM CENTER BRANCH  1.361076e+06  1.370987e+06
# BCSB - MUNI MAIN OFFICE            7.658752e+05  9.398682e+05
# BCSB - MUNI NB ASHLEY BLVD BRANCH  8.092433e+05  7.842536e+05
# BCSB - MUNI REHOBOTH BRANCH        2.514710e+05  6.614460e+05
# BCSB - ATTLEBORO HIGH SCHOOL       4.329124e+05  4.167262e+05
# BCSB - CONTACT CENTER              2.108250e+05  3.031106e+05
# BCSB - MUNI EAST FREETOWN BRANCH   1.674970e+05  2.814430e+05
# BCSB - MUNI NORTH RAYNHAM BRANCH   3.713180e+05  2.294839e+05
# BCSB - MUNI COUNTY STREET BRANCH   5.503060e+03  0.000000e+00
# BCSB - MUNI FRANKLIN BRANCH        1.708192e+05  0.000000e+00
# BCSB - NB ROCKDALE AVE BRANCH      0.000000e+00  0.000000e+00
# BCSB - WALMART BRANCH              0.000000e+00  0.000000e+00

# %%
### This should be the first part, 5 Year History of Branches

# %%
data_current = run_data_cleaning_pipeline(
    as_of_date=datetime(2025, 6, 30),
    data_source="production",
    exclude_org_types=["MUNI","TRST"]
)
# Out:
# Starting data cleaning pipeline for 2025-06-30
# Using data source: production
# Excluding organization types: ['MUNI', 'TRST']
#
# === Step 1: Loading supporting data ===
# Loaded production data from database
#
# === Step 2: Generating account data for 2025-06-30 ===
# Generated 89805 account records
# Account types: {'CK': 37205, 'SAV': 16063, 'CNS': 15735, 'TD': 9501, 'MTG': 4457, 'CML': 3390, 'LEAS': 1792, 'RTMT': 1646, 'BKCK': 12, 'MLN': 4}
#
# === Step 3: Merging with organizations (excluding ['MUNI', 'TRST']) ===
# Excluded 1832 records with organization types: ['MUNI', 'TRST']
# After organization merge and filtering: 87973 accounts
#
# === Step 4: Merging with persons to append DOB ===
# After person merge: 87973 accounts (77230 with person data)
#
# === Step 5: Appending address information ===
# Organization accounts: 10609
# Person accounts: 77364
# Other accounts (no customer link): 0
# Organization accounts with addresses: 10593/10609
# Person accounts with addresses: 77357/77364
#
# === Pipeline Complete ===
# Final dataset: 87973 accounts with 108 columns
# Accounts with address data: 87950/87973 (100.0%)
#
# Account type summary:
#   CK: 35732
#   SAV: 16018
#   CNS: 15735
#   TD: 9320
#   MTG: 4457
#   CML: 3259
#   LEAS: 1792
#   RTMT: 1644
#   BKCK: 12
#   MLN: 4

# %%
import numpy as np

# %%
data_current['Primary Key'] = np.where(
    data_current['taxrptfororgnbr'].isnull(), 
    'P' + data_current['taxrptforpersnbr'].astype(str), 
    'O' + data_current['taxrptfororgnbr'].astype(str)
)

# %%
def concat_address(text1, text2, text3):
    parts = [str(p).strip() for p in [text1, text2, text3] if p and str(p).strip()]
    return ' '.join(parts) if parts else pd.NA

data_current['Address'] = data_current.apply(
    lambda row: concat_address(row.get('text1'), row.get('text2'), row.get('text3')),
    axis=1
)

# %%
data_current = data_current[data_current['mjaccttypcd'].isin(['CML','MLN','CNS','MTG','CK','SAV','TD'])].copy()

# %%
data_current = data_current[~data_current['currmiaccttypcd'].isin(['CI07'])].copy()

# %%
def map_account_type(acct_code:str):
    """
    Map mjaccttypcd to friendly Account Type
    """
    mapping = {
        'CML':'Commercial Loan',
        'MLN':'Commercial Loan',
        'CNS':'Consumer Loan',
        'MTG':'Residential Loan',
        'CK':'Checking',
        'SAV':'Savings',
        'TD':'CD'
    }
    return mapping.get(str(acct_code).upper(), 'Other')

data_current['Account Type'] = data_current['mjaccttypcd'].apply(map_account_type)

# %%
data_current['orig_ttl_loan_amt'] = np.where(
    data_current['mjaccttypcd'].isin(['CML','MLN','MTG','CNS']),
    data_current['orig_ttl_loan_amt'],
    pd.NA
)

# %%
data_current['Business/Individual'] = np.where(
    data_current['taxrptfororgnbr'].isnull(),
    'Individual',
    'Business'
)

# %%
data_current
# Out:
#          effdate    acctnbr  \
# 1     2025-06-30  150936915
# 2     2025-06-30  151058057
# 3     2025-06-30   60801557
# 5     2025-06-30  150862011
# 6     2025-06-30  151038843
# ...          ...        ...
# 87968 2025-06-30   26266946
# 87969 2025-06-30  151036863
# 87970 2025-06-30  150635426
# 87971 2025-06-30  150318973
# 87972 2025-06-30   28163508
#
#                                            ownersortname  \
# 1                                REDBROOK APARTMENTS LLC
# 2                                     NBPIV SARATOGA LLC
# 3      COMMUNITY COUNSELING OF BRISTOL COUNTY, INCORP...
# 5                                R3 PROJECT COMPANY, LLC
# 6                                         POWER 250, LLC
# ...                                                  ...
# 87968                                MANGELS, RICHARD A.
# 87969                              ZUSCHLAG, JENNIFER L.
# 87970                                  HOWLAND, KERRY A.
# 87971                                  COLON, DEVANTE L.
# 87972                                     COSMO, JOEL A.
#
#                             product  noteopenamt ratetypcd mjaccttypcd  \
# 1              Commercial Mortgages   65500000.0       VAR         CML
# 2              Commercial Mortgages   26000000.0       FIX         CML
# 3      Investment Business Checking          0.0       VAR          CK
# 5            CML Fixed Construction   20000000.0       FIX         CML
# 6              CML ARM Construction   27500000.0       VAR         CML
# ...                             ...          ...       ...         ...
# 87968         eChecking (18 & over)          0.0      None          CK
# 87969           Prime Time Checking      40000.0       VAR          CK
# 87970                Basic Checking        100.0      None          CK
# 87971         eChecking (18 & over)        400.0      None          CK
# 87972           Prime Time Checking          0.0       VAR          CK
#
#       currmiaccttypcd curracctstatcd  noteintrate  ...            text2  \
# 1                CM40            ACT     0.065722  ...             None
# 2                CM40            ACT     0.063500  ...             None
# 3                CK28            ACT     0.022000  ...  1 WASHINGTON ST
# 5                CM07            ACT     0.065000  ...             None
# 6                CM08            ACT     0.070696  ...             None
# ...               ...            ...          ...  ...              ...
# 87968            CK04            ACT     0.000000  ...             None
# 87969            CK06            ACT     0.000300  ...             None
# 87970            CK02            ACT     0.000000  ...             None
# 87971            CK04            ACT     0.000000  ...             None
# 87972            CK06            ACT     0.000300  ...             None
#
#        text3      cityname statecd  zipcd orgnbr persnbr_x persnbr_y  \
# 1       None     BRAINTREE      MA  02184    NaN       NaN       NaN
# 2       None     WAKEFIELD      MA  01880    NaN       NaN       NaN
# 3       None       TAUNTON      MA  02780    NaN       NaN       NaN
# 5       None        QUINCY      MA  02169    NaN       NaN       NaN
# 6       None  EAST WALPOLE      MA  02032    NaN       NaN       NaN
# ...      ...           ...     ...    ...    ...       ...       ...
# 87968   None    MIDDLEBORO      MA  02346    NaN   1046949   1046949
# 87969   None     ATTLEBORO      MA  02703    NaN   1155942   1155942
# 87970   None   NEW BEDFORD      MA  02744    NaN   1135101   1135101
# 87971   None     ATTLEBORO      MA  02703    NaN   1100117   1100117
# 87972   None   NEW BEDFORD      MA  02745    NaN   1049071   1049071
#
#        Primary Key                                         Address
# 1         O1012222                            ONE CAMPANELLI DRIVE
# 2         O1016877                   401 EDGEWATER PLACE SUITE 265
# 3         O1000047  MILL RIVER PROFESSIONAL CENTER 1 WASHINGTON ST
# 5         O1015409                                    1512 HANCOCK
# 6         O1012385                                108 ENDEAN DRIVE
# ...            ...                                             ...
# 87968     P1046949                        64 OLD CENTER ROAD APT 3
# 87969     P1155942                               204 PINE ST APT 3
# 87970     P1135101                                 11 DESAUTELS CT
# 87971     P1100117                                197 ROBINSON AVE
# 87972     P1049071                               1114 CHURCHILL ST
#
# [84525 rows x 110 columns]

# %%
data_current = data_current.rename(columns={
    'cityname':'City',
    'statecd':'State',
    'zipcd':'Zip',
    'branchname':'Branch Associated',
    'contractdate':'Date Account Opened',
    'Net Balance':'Current Balance',
    'orig_ttl_loan_amt':'Original Balance (Loans)',
    'datebirth':'Date of Birth'
}).copy()

# %%
data_current.columns.to_list()
# Out:
# ['effdate',
#  'acctnbr',
#  'ownersortname',
#  'product',
#  'noteopenamt',
#  'ratetypcd',
#  'mjaccttypcd',
#  'currmiaccttypcd',
#  'curracctstatcd',
#  'noteintrate',
#  'bookbalance',
#  'notebal',
#  'contractdate',
#  'datemat',
#  'taxrptfororgnbr',
#  'taxrptforpersnbr',
#  'loanofficer',
#  'acctofficer',
#  'creditlimitamt',
#  'origintrate',
#  'marginfixed',
#  'fdiccatcd',
#  'amortterm',
#  'totalpctsold',
#  'cobal',
#  'credlimitclatresamt',
#  'riskratingcd',
#  'origdate',
#  'currterm',
#  'loanidx',
#  'rcf',
#  'availbalamt',
#  'fdiccatdesc',
#  'origbal',
#  'loanlimityn',
#  'Net Balance',
#  'Net Available',
#  'Net Collateral Reserve',
#  'Total Exposure',
#  'orig_ttl_loan_amt',
#  'portfolio_key',
#  'ownership_key',
#  'address_key',
#  'householdnbr',
#  'datelastmaint_x',
#  'Category',
#  'inactivedate',
#  'branchname',
#  'primaryownercity',
#  'primaryownerstate',
#  'orgnbr_x',
#  'orgname',
#  'orgtypcd',
#  'orgtypcddesc',
#  'taxid_x',
#  'taxidtypcd',
#  'rpt1099intyn',
#  'privacyyn_x',
#  'taxexemptyn',
#  'cipratingcd_x',
#  'creditscore_x',
#  'siccd_x',
#  'siccddesc',
#  'sicsubcd_x',
#  'sicsubcddesc',
#  'naicscd_x',
#  'naicscddesc',
#  'datelastmaint_y',
#  'rundate_x',
#  'allowpromoyn_x',
#  'homeemail_x',
#  'busemail_x',
#  'persnbr',
#  'persname',
#  'perssortname',
#  'taxid_y',
#  'datebirth',
#  'datedeath',
#  'age',
#  'employeeyn',
#  'privacyyn_y',
#  'cipratingcd_y',
#  'naicscd_y',
#  'naicsdesc',
#  'siccd_y',
#  'sicdesc',
#  'sicsubcd_y',
#  'sicsubdesc',
#  'creditscore_y',
#  'spousepersnbr',
#  'spousepersname',
#  'spouseperssortname',
#  'datelastmaint',
#  'rundate_y',
#  'allowpromoyn_y',
#  'homeemail_y',
#  'busemail_y',
#  'orgnbr_y',
#  'addrnbr',
#  'text1',
#  'text2',
#  'text3',
#  'cityname',
#  'statecd',
#  'zipcd',
#  'orgnbr',
#  'persnbr_x',
#  'persnbr_y',
#  'Primary Key',
#  'Address']

# %%
data_current_final = data_current[[
    'Primary Key',
    'Address',
    'City',
    'State',
    'Zip',
    'Branch Associated',
    'Account Type',
    'Date Account Opened',
    'Current Balance',
    'Original Balance (Loans)',
    'Date of Birth'
]].copy()

# %%
data_current_final
# Out:
#       Primary Key                                         Address  \
# 1        O1012222                            ONE CAMPANELLI DRIVE
# 2        O1016877                   401 EDGEWATER PLACE SUITE 265
# 3        O1000047  MILL RIVER PROFESSIONAL CENTER 1 WASHINGTON ST
# 5        O1015409                                    1512 HANCOCK
# 6        O1012385                                108 ENDEAN DRIVE
# ...           ...                                             ...
# 87968    P1046949                        64 OLD CENTER ROAD APT 3
# 87969    P1155942                               204 PINE ST APT 3
# 87970    P1135101                                 11 DESAUTELS CT
# 87971    P1100117                                197 ROBINSON AVE
# 87972    P1049071                               1114 CHURCHILL ST
#
#                City State    Zip                Branch Associated  \
# 1         BRAINTREE    MA  02184   BCSB - COMM'L LENDING- TAUNTON
# 2         WAKEFIELD    MA  01880   BCSB - COMM'L LENDING- TAUNTON
# 3           TAUNTON    MA  02780               BCSB - MAIN OFFICE
# 5            QUINCY    MA  02169   BCSB - COMM'L LENDING- TAUNTON
# 6      EAST WALPOLE    MA  02032  BCSB - COMM'L LENDING - WARWICK
# ...             ...   ...    ...                              ...
# 87968    MIDDLEBORO    MA  02346      BCSB - COUNTY STREET BRANCH
# 87969     ATTLEBORO    MA  02703          BCSB - ATTLEBORO BRANCH
# 87970   NEW BEDFORD    MA  02744     BCSB - NB ASHLEY BLVD BRANCH
# 87971     ATTLEBORO    MA  02703      BCSB - COUNTY STREET BRANCH
# 87972   NEW BEDFORD    MA  02745     BCSB - NB ASHLEY BLVD BRANCH
#
#           Account Type Date Account Opened  Current Balance  \
# 1      Commercial Loan          2023-09-12      29000000.00
# 2      Commercial Loan          2024-06-05      26000000.00
# 3             Checking          2012-03-05      22759792.20
# 5      Commercial Loan          2023-03-07             0.00
# 6      Commercial Loan          2024-04-22       2254909.06
# ...                ...                 ...              ...
# 87968         Checking          2016-06-29          -858.81
# 87969         Checking          2024-04-15          -859.40
# 87970         Checking          2021-07-26          -887.91
# 87971         Checking          2019-05-13         -1032.68
# 87972         Checking          2018-03-01         -1156.10
#
#       Original Balance (Loans) Date of Birth
# 1                   65500000.0           NaT
# 2                   26000000.0           NaT
# 3                         <NA>           NaT
# 5                   20000000.0           NaT
# 6                   27500000.0           NaT
# ...                        ...           ...
# 87968                     <NA>    1961-01-20
# 87969                     <NA>    1974-10-28
# 87970                     <NA>    1971-11-25
# 87971                     <NA>    1993-12-26
# 87972                     <NA>    1984-03-13
#
# [83966 rows x 11 columns]

# %%
summary
# Out:
#                            branchname  total_deposit_balance
# 12                 BCSB - Main Office           2.754074e+08
# 0             BCSB - Attleboro Branch           2.251015e+08
# 25         BCSB - No Attleboro Branch           1.821693e+08
# 28       BCSB - Raynham Center Branch           1.632555e+08
# 29             BCSB - Rehoboth Branch           1.332619e+08
# 27            BCSB - Pawtucket Branch           1.259627e+08
# 26        BCSB - North Raynham Branch           1.198817e+08
# 6             BCSB - Dartmouth Branch           1.031703e+08
# 4         BCSB - County Street Branch           9.080247e+07
# 23       BCSB - NB Ashley Blvd Branch           6.240310e+07
# 9            BCSB - Fall River Branch           5.450023e+07
# 11                  BCSB - Greenville           4.862586e+07
# 5                   BCSB - Cumberland           4.344918e+07
# 24      BCSB - NB Rockdale Ave Branch           3.510350e+07
# 10             BCSB - Franklin Branch           3.499732e+07
# 8         BCSB - East Freetown Branch           3.386432e+07
# 2           BCSB - Candleworks Branch           3.053180e+07
# 31              BCSB - Walmart Branch           1.702878e+07
# 3               BCSB - Contact Center           1.286719e+07
# 30         BCSB - Taunton High School           3.180596e+06
# 18            BCSB - Muni Main Office           1.788479e+06
# 21  BCSB - Muni Raynham Center Branch           1.278270e+06
# 15       BCSB - Muni Dartmouth Branch           8.315855e+05
# 20   BCSB - Muni North Raynham Branch           5.760020e+05
# 13     BCSB - Muni Candleworks Branch           5.477447e+05
# 17        BCSB - Muni Franklin Branch           5.039386e+05
# 1        BCSB - Attleboro High School           2.967913e+05
# 16   BCSB - Muni East Freetown Branch           2.212932e+05
# 22        BCSB - Muni Rehoboth Branch           2.009485e+05
# 14   BCSB - Muni County Street Branch           1.059800e+05
# 7           BCSB - Deposit Operations           9.547377e+04
# 19  BCSB - Muni NB Ashley Blvd Branch           3.878970e+03

# %%
summary['total_deposit_balance'].sum()
# Out:
# np.float64(1802015043.04)

# %%
specified_date = datetime(2020, 12, 31)
data2020 = query_df_on_date(specified_date)
data2020
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91019 entries, 0 to 91018
# Data columns (total 47 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   effdate                 91019 non-null  datetime64[ns]
#  1   acctnbr                 91019 non-null  object
#  2   ownersortname           91019 non-null  object
#  3   product                 91019 non-null  object
#  4   noteopenamt             91019 non-null  float64
#  5   ratetypcd               72634 non-null  object
#  6   mjaccttypcd             91019 non-null  object
#  7   currmiaccttypcd         91019 non-null  object
#  8   curracctstatcd          91019 non-null  object
#  9   noteintrate             91019 non-null  float64
#  10  bookbalance             91019 non-null  float64
#  11  notebal                 91019 non-null  float64
#  12  contractdate            91019 non-null  datetime64[ns]
#  13  datemat                 34802 non-null  datetime64[ns]
#  14  taxrptfororgnbr         12589 non-null  float64
#  15  taxrptforpersnbr        78430 non-null  float64
#  16  loanofficer             27590 non-null  object
#  17  acctofficer             48964 non-null  object
#  18  creditlimitamt          91019 non-null  float64
#  19  origintrate             26959 non-null  object
#  20  marginfixed             27608 non-null  object
#  21  fdiccatcd               26977 non-null  object
#  22  amortterm               27608 non-null  float64
#  23  totalpctsold            91019 non-null  float64
#  24  cobal                   91019 non-null  float64
#  25  credlimitclatresamt     91019 non-null  float64
#  26  riskratingcd            3175 non-null   object
#  27  origdate                27248 non-null  datetime64[ns]
#  28  currterm                27608 non-null  float64
#  29  loanidx                 27601 non-null  object
#  30  rcf                     2782 non-null   object
#  31  availbalamt             91019 non-null  float64
#  32  fdiccatdesc             26977 non-null  object
#  33  origbal                 25950 non-null  float64
#  34  loanlimityn             27608 non-null  object
#  35  Net Balance             91019 non-null  float64
#  36  Net Available           91019 non-null  float64
#  37  Net Collateral Reserve  91019 non-null  float64
#  38  Total Exposure          91019 non-null  float64
#  39  orig_ttl_loan_amt       91019 non-null  float64
#  40  portfolio_key           76584 non-null  float64
#  41  ownership_key           76584 non-null  float64
#  42  address_key             76584 non-null  float64
#  43  householdnbr            70282 non-null  float64
#  44  datelastmaint           70282 non-null  datetime64[ns]
#  45  Category                27608 non-null  object
#  46  inactivedate            2301 non-null   datetime64[ns]
# dtypes: datetime64[ns](6), float64(23), object(18)
# memory usage: 32.6+ MB
#          effdate    acctnbr                  ownersortname  \
# 0     2020-12-31  150200005  MoneyGram Payment Systems Inc
# 1     2020-12-31   61053112                City Of Taunton
# 2     2020-12-31  150544263        REDBROOK APARTMENTS LLC
# 3     2020-12-31   60436522       Hodess Construction Corp
# 4     2020-12-31    6252261        Hutchens Holding II LLC
# ...          ...        ...                            ...
# 91014 2020-12-31  150291616            Fisher, Aquinnah C.
# 91015 2020-12-31  150513086              Brooks, Cadeem C.
# 91016 2020-12-31   27039064    Bristol County Savings Bank
# 91017 2020-12-31  150337783    Bristol County Savings Bank
# 91018 2020-12-31   27020568    Bristol County Savings Bank
#
#                             product  noteopenamt ratetypcd mjaccttypcd  \
# 0                 Treasurer's Check          0.0      None        BKCK
# 1            Municipal Money Market          0.0       VAR          CK
# 2              Commercial Mortgages   42000000.0       VAR         CML
# 3      Investment Business Checking          0.0       VAR          CK
# 4          Commercial Swap Mortgage   13405500.0       VAR         CML
# ...                             ...          ...       ...         ...
# 91014               eChecking 16/17        100.0      None          CK
# 91015                Basic Checking         50.0      None          CK
# 91016      Escrow Checks Processing          0.0      None        BKCK
# 91017             Business Checking          0.0      None          CK
# 91018              PDO Checks - OLD          0.0      None        BKCK
#
#       currmiaccttypcd curracctstatcd  noteintrate  ...  portfolio_key  \
# 0                TRCK            ACT     0.000000  ...        41516.0
# 1                CK18            ACT     0.001500  ...         4183.0
# 2                CM40            ACT     0.030000  ...        57113.0
# 3                CK28            ACT     0.002000  ...         3315.0
# 4                CM43            ACT     0.026586  ...         3996.0
# ...               ...            ...          ...  ...            ...
# 91014            CK03            ACT     0.000000  ...            NaN
# 91015            CK02            ACT     0.000000  ...            NaN
# 91016            BTC3            ACT     0.000000  ...         1221.0
# 91017            CK12            ACT     0.000000  ...         1221.0
# 91018            BTC1            ACT     0.000000  ...         1221.0
#
#        ownership_key address_key householdnbr       datelastmaint  Category  \
# 0            43261.0     44260.0     187340.0 2020-02-26 23:28:03       NaN
# 1            33668.0     33967.0      97724.0 2020-02-26 23:28:03       NaN
# 2            59661.0     61147.0     193906.0 2021-12-07 13:23:49       CRE
# 3             3942.0      4388.0     241524.0 2022-09-08 22:14:08       NaN
# 4             4209.0      4432.0     230789.0 2024-07-29 12:35:49       CRE
# ...              ...         ...          ...                 ...       ...
# 91014            NaN         NaN          NaN                 NaT       NaN
# 91015            NaN         NaN          NaN                 NaT       NaN
# 91016         1352.0     41577.0     255924.0 2022-09-27 22:46:27       NaN
# 91017         1352.0     51094.0     255924.0 2022-09-27 22:46:27       NaN
# 91018         1352.0     41437.0     255924.0 2022-09-27 22:46:27       NaN
#
#       inactivedate                           branchname  primaryownercity  \
# 0              NaT                   BCSB - Main Office       Minneapolis
# 1              NaT              BCSB - Muni Main Office           Taunton
# 2              NaT       BCSB - Comm'l Lending- Taunton         Braintree
# 3              NaT           BCSB - No Attleboro Branch   North Attleboro
# 4              NaT  BCSB - Comm'l Lending - Candleworks        Fall River
# ...            ...                                  ...               ...
# 91014          NaT                BCSB - Walmart Branch           Taunton
# 91015          NaT          BCSB - North Raynham Branch            Lowell
# 91016          NaT                   BCSB - Main Office           Taunton
# 91017          NaT                BCSB - Contact Center           Taunton
# 91018          NaT                   BCSB - Main Office           Taunton
#
#       primaryownerstate
# 0                    MN
# 1                    MA
# 2                    MA
# 3                    MA
# 4                    MA
# ...                 ...
# 91014                MA
# 91015                MA
# 91016                MA
# 91017                MA
# 91018                MA
#
# [91019 rows x 50 columns]

# %%
specified_date = datetime(2021, 12, 31)
data2021 = query_df_on_date(specified_date)
data2021
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88944 entries, 0 to 88943
# Data columns (total 47 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   effdate                 88944 non-null  datetime64[ns]
#  1   acctnbr                 88944 non-null  object
#  2   ownersortname           88944 non-null  object
#  3   product                 88944 non-null  object
#  4   noteopenamt             88944 non-null  float64
#  5   ratetypcd               70453 non-null  object
#  6   mjaccttypcd             88944 non-null  object
#  7   currmiaccttypcd         88944 non-null  object
#  8   curracctstatcd          88944 non-null  object
#  9   noteintrate             88944 non-null  float64
#  10  bookbalance             88944 non-null  float64
#  11  notebal                 88944 non-null  float64
#  12  contractdate            88944 non-null  datetime64[ns]
#  13  datemat                 32646 non-null  datetime64[ns]
#  14  taxrptfororgnbr         11705 non-null  float64
#  15  taxrptforpersnbr        77239 non-null  float64
#  16  loanofficer             26071 non-null  object
#  17  acctofficer             46120 non-null  object
#  18  creditlimitamt          88944 non-null  float64
#  19  origintrate             25354 non-null  object
#  20  marginfixed             26091 non-null  object
#  21  fdiccatcd               25393 non-null  object
#  22  amortterm               26091 non-null  float64
#  23  totalpctsold            88944 non-null  float64
#  24  cobal                   88944 non-null  float64
#  25  credlimitclatresamt     88944 non-null  float64
#  26  riskratingcd            2158 non-null   object
#  27  origdate                25735 non-null  datetime64[ns]
#  28  currterm                26091 non-null  float64
#  29  loanidx                 26087 non-null  object
#  30  rcf                     2653 non-null   object
#  31  availbalamt             88944 non-null  float64
#  32  fdiccatdesc             25393 non-null  object
#  33  origbal                 24445 non-null  float64
#  34  loanlimityn             26091 non-null  object
#  35  Net Balance             88944 non-null  float64
#  36  Net Available           88944 non-null  float64
#  37  Net Collateral Reserve  88944 non-null  float64
#  38  Total Exposure          88944 non-null  float64
#  39  orig_ttl_loan_amt       88944 non-null  float64
#  40  portfolio_key           78548 non-null  float64
#  41  ownership_key           78548 non-null  float64
#  42  address_key             78548 non-null  float64
#  43  householdnbr            71460 non-null  float64
#  44  datelastmaint           71460 non-null  datetime64[ns]
#  45  Category                26091 non-null  object
#  46  inactivedate            2411 non-null   datetime64[ns]
# dtypes: datetime64[ns](6), float64(23), object(18)
# memory usage: 31.9+ MB
#          effdate     acctnbr                    ownersortname  \
# 0     2021-12-31   150200005    MoneyGram Payment Systems Inc
# 1     2021-12-31    61053112                  City Of Taunton
# 2     2021-12-31    60436522  Hodess Construction Corporation
# 3     2021-12-31  4426080386                Barry, Richard L.
# 4     2021-12-31    60032826                City Of Attleboro
# ...          ...         ...                              ...
# 88939 2021-12-31    27059932     Willow Tree Poultry Farm Inc
# 88940 2021-12-31   150569667      Bristol County Savings Bank
# 88941 2021-12-31    27039064      Bristol County Savings Bank
# 88942 2021-12-31   150337783      Bristol County Savings Bank
# 88943 2021-12-31    27020568      Bristol County Savings Bank
#
#                             product  noteopenamt ratetypcd mjaccttypcd  \
# 0                 Treasurer's Check          0.0      None        BKCK
# 1            Municipal Money Market          0.0       VAR          CK
# 2      Investment Business Checking          0.0       VAR          CK
# 3                 Statement Savings          0.0       VAR         SAV
# 4                     Municipal Now          0.0       VAR          CK
# ...                             ...          ...       ...         ...
# 88939             Business Checking          0.0      None          CK
# 88940             Business Checking          0.0      None          CK
# 88941      Escrow Checks Processing          0.0      None        BKCK
# 88942             Business Checking          0.0      None          CK
# 88943              PDO Checks - OLD          0.0      None        BKCK
#
#       currmiaccttypcd curracctstatcd  noteintrate  ...  portfolio_key  \
# 0                TRCK            ACT       0.0000  ...        41516.0
# 1                CK18            ACT       0.0010  ...         4183.0
# 2                CK28            ACT       0.0015  ...         3315.0
# 3                SV02            ACT       0.0005  ...            NaN
# 4                CK27            ACT       0.0003  ...         5106.0
# ...               ...            ...          ...  ...            ...
# 88939            CK12            ACT       0.0000  ...        33010.0
# 88940            CK12            ACT       0.0000  ...         1221.0
# 88941            BTC3            ACT       0.0000  ...         1221.0
# 88942            CK12            ACT       0.0000  ...         1221.0
# 88943            BTC1            ACT       0.0000  ...         1221.0
#
#        ownership_key address_key householdnbr       datelastmaint  Category  \
# 0            43261.0     44260.0     187340.0 2020-02-26 23:28:03       NaN
# 1            33668.0     33967.0      97724.0 2020-02-26 23:28:03       NaN
# 2             3942.0      4388.0     241524.0 2022-09-08 22:14:08       NaN
# 3                NaN         NaN          NaN                 NaT       NaN
# 4            35118.0     35620.0     206654.0 2024-04-29 22:10:12       NaN
# ...              ...         ...          ...                 ...       ...
# 88939        33626.0     33919.0     191089.0 2020-02-26 23:28:03       NaN
# 88940         1352.0     62702.0          NaN                 NaT       NaN
# 88941         1352.0     41577.0     255924.0 2022-09-27 22:46:27       NaN
# 88942         1352.0     51094.0     255924.0 2022-09-27 22:46:27       NaN
# 88943         1352.0     41437.0     255924.0 2022-09-27 22:46:27       NaN
#
#       inactivedate                    branchname  primaryownercity  \
# 0              NaT            BCSB - Main Office       Minneapolis
# 1              NaT       BCSB - Muni Main Office           Taunton
# 2              NaT    BCSB - No Attleboro Branch   North Attleboro
# 3              NaT    BCSB - No Attleboro Branch         ATTLEBORO
# 4              NaT  BCSB - Muni Attleboro Branch         Attleboro
# ...            ...                           ...               ...
# 88939          NaT       BCSB - Attleboro Branch         Attleboro
# 88940          NaT     BCSB - Deposit Operations           Taunton
# 88941          NaT            BCSB - Main Office           Taunton
# 88942          NaT         BCSB - Contact Center           Taunton
# 88943          NaT            BCSB - Main Office           Taunton
#
#       primaryownerstate
# 0                    MN
# 1                    MA
# 2                    MA
# 3                    MA
# 4                    MA
# ...                 ...
# 88939                MA
# 88940                MA
# 88941                MA
# 88942                MA
# 88943                MA
#
# [88944 rows x 50 columns]

# %%
specified_date = datetime(2022, 12, 30)
data2022 = query_df_on_date(specified_date)
data2022
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88835 entries, 0 to 88834
# Data columns (total 47 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   effdate                 88835 non-null  datetime64[ns]
#  1   acctnbr                 88835 non-null  object
#  2   ownersortname           88835 non-null  object
#  3   product                 88835 non-null  object
#  4   noteopenamt             88835 non-null  float64
#  5   ratetypcd               70564 non-null  object
#  6   mjaccttypcd             88835 non-null  object
#  7   currmiaccttypcd         88835 non-null  object
#  8   curracctstatcd          88835 non-null  object
#  9   noteintrate             88835 non-null  float64
#  10  bookbalance             88835 non-null  float64
#  11  notebal                 88835 non-null  float64
#  12  contractdate            88835 non-null  datetime64[ns]
#  13  datemat                 32872 non-null  datetime64[ns]
#  14  taxrptfororgnbr         11733 non-null  float64
#  15  taxrptforpersnbr        77102 non-null  float64
#  16  loanofficer             26631 non-null  object
#  17  acctofficer             58339 non-null  object
#  18  creditlimitamt          88835 non-null  float64
#  19  origintrate             25818 non-null  object
#  20  marginfixed             26631 non-null  object
#  21  fdiccatcd               25869 non-null  object
#  22  amortterm               26631 non-null  float64
#  23  totalpctsold            88835 non-null  float64
#  24  cobal                   88835 non-null  float64
#  25  credlimitclatresamt     88835 non-null  float64
#  26  riskratingcd            1938 non-null   object
#  27  origdate                26289 non-null  datetime64[ns]
#  28  currterm                26631 non-null  float64
#  29  loanidx                 26626 non-null  object
#  30  rcf                     2679 non-null   object
#  31  availbalamt             88835 non-null  float64
#  32  fdiccatdesc             25869 non-null  object
#  33  origbal                 24996 non-null  float64
#  34  loanlimityn             26631 non-null  object
#  35  Net Balance             88835 non-null  float64
#  36  Net Available           88835 non-null  float64
#  37  Net Collateral Reserve  88835 non-null  float64
#  38  Total Exposure          88835 non-null  float64
#  39  orig_ttl_loan_amt       88835 non-null  float64
#  40  portfolio_key           83453 non-null  float64
#  41  ownership_key           83453 non-null  float64
#  42  address_key             83453 non-null  float64
#  43  householdnbr            75272 non-null  float64
#  44  datelastmaint           75272 non-null  datetime64[ns]
#  45  Category                26631 non-null  object
#  46  inactivedate            2537 non-null   datetime64[ns]
# dtypes: datetime64[ns](6), float64(23), object(18)
# memory usage: 31.9+ MB
#          effdate    acctnbr                  ownersortname  \
# 0     2022-12-30  150200005  MONEYGRAM PAYMENT SYSTEMS INC
# 1     2022-12-30  150833377            Alice Building, LLC
# 2     2022-12-30   60032826              CITY OF ATTLEBORO
# 3     2022-12-30  150586025       GREATER FALL RIVER V.S.D
# 4     2022-12-30  150809211           29 CENTER STREET LLC
# ...          ...        ...                            ...
# 88830 2022-12-30  150818907                 BURY, CAROL A.
# 88831 2022-12-30  150569667    BRISTOL COUNTY SAVINGS BANK
# 88832 2022-12-30   27039064    BRISTOL COUNTY SAVINGS BANK
# 88833 2022-12-30  150337783    BRISTOL COUNTY SAVINGS BANK
# 88834 2022-12-30   27020568    BRISTOL COUNTY SAVINGS BANK
#
#                         product  noteopenamt ratetypcd mjaccttypcd  \
# 0             Treasurer's Check          0.0      None        BKCK
# 1          Commercial Mortgages   37275000.0       FIX         CML
# 2                 Municipal Now          0.0       VAR          CK
# 3                 Municipal Now          0.0       VAR          CK
# 4          Commercial Mortgages   18000000.0       FIX         CML
# ...                         ...          ...       ...         ...
# 88830     eChecking (18 & over)         10.0      None          CK
# 88831         Business Checking          0.0      None          CK
# 88832  Escrow Checks Processing          0.0      None        BKCK
# 88833         Business Checking          0.0      None          CK
# 88834          PDO Checks - OLD          0.0      None        BKCK
#
#       currmiaccttypcd curracctstatcd  noteintrate  ...  portfolio_key  \
# 0                TRCK            ACT       0.0000  ...        41516.0
# 1                CM40            ACT       0.0575  ...        71066.0
# 2                CK27            ACT       0.0003  ...         5106.0
# 3                CK27            ACT       0.0003  ...        40677.0
# 4                CM40            ACT       0.0490  ...         3864.0
# ...               ...            ...          ...  ...            ...
# 88830            CK04            ACT       0.0000  ...            NaN
# 88831            CK12           DORM       0.0000  ...         1221.0
# 88832            BTC3            ACT       0.0000  ...         1221.0
# 88833            CK12            ACT       0.0000  ...         1221.0
# 88834            BTC1            ACT       0.0000  ...         1221.0
#
#        ownership_key address_key householdnbr       datelastmaint  Category  \
# 0            43261.0     44260.0     187340.0 2020-02-26 23:28:03       NaN
# 1            74531.0     76376.0     260303.0 2022-12-23 22:25:51       CRE
# 2            35118.0     35620.0     206654.0 2024-04-29 22:10:12       NaN
# 3            42158.0     43236.0     185474.0 2021-03-25 22:19:28       NaN
# 4            48607.0     75391.0     229910.0 2022-11-03 14:12:28       CRE
# ...              ...         ...          ...                 ...       ...
# 88830            NaN         NaN          NaN                 NaT       NaN
# 88831         1352.0     62702.0          NaN                 NaT       NaN
# 88832         1352.0     41577.0     255924.0 2022-09-27 22:46:27       NaN
# 88833         1352.0     51094.0     255924.0 2022-09-27 22:46:27       NaN
# 88834         1352.0     41437.0     255924.0 2022-09-27 22:46:27       NaN
#
#       inactivedate                      branchname  primaryownercity  \
# 0              NaT              BCSB - MAIN OFFICE       MINNEAPOLIS
# 1              NaT  BCSB - COMM'L LENDING- TAUNTON        Providence
# 2              NaT    BCSB - MUNI ATTLEBORO BRANCH         ATTLEBORO
# 3              NaT   BCSB - MUNI FALL RIVER BRANCH        FALL RIVER
# 4              NaT  BCSB - COMM'L LENDING- TAUNTON           Taunton
# ...            ...                             ...               ...
# 88830          NaT              BCSB - MAIN OFFICE      East Taunton
# 88831          NaT       BCSB - DEPOSIT OPERATIONS           TAUNTON
# 88832          NaT              BCSB - MAIN OFFICE           TAUNTON
# 88833          NaT           BCSB - CONTACT CENTER           TAUNTON
# 88834          NaT              BCSB - MAIN OFFICE           TAUNTON
#
#       primaryownerstate
# 0                    MN
# 1                    RI
# 2                    MA
# 3                    MA
# 4                    MA
# ...                 ...
# 88830                MA
# 88831                MA
# 88832                MA
# 88833                MA
# 88834                MA
#
# [88835 rows x 50 columns]

# %%
specified_date = datetime(2023, 12, 29)
data2023 = query_df_on_date(specified_date)
data2023
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90750 entries, 0 to 90749
# Data columns (total 47 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   effdate                 90750 non-null  datetime64[ns]
#  1   acctnbr                 90750 non-null  object
#  2   ownersortname           90750 non-null  object
#  3   product                 90750 non-null  object
#  4   noteopenamt             90750 non-null  float64
#  5   ratetypcd               72775 non-null  object
#  6   mjaccttypcd             90750 non-null  object
#  7   currmiaccttypcd         90750 non-null  object
#  8   curracctstatcd          90750 non-null  object
#  9   noteintrate             90750 non-null  float64
#  10  bookbalance             90750 non-null  float64
#  11  notebal                 90750 non-null  float64
#  12  contractdate            90750 non-null  datetime64[ns]
#  13  datemat                 34808 non-null  datetime64[ns]
#  14  taxrptfororgnbr         11906 non-null  float64
#  15  taxrptforpersnbr        78844 non-null  float64
#  16  loanofficer             26160 non-null  object
#  17  acctofficer             60869 non-null  object
#  18  creditlimitamt          90750 non-null  float64
#  19  origintrate             25316 non-null  object
#  20  marginfixed             26160 non-null  object
#  21  fdiccatcd               25364 non-null  object
#  22  amortterm               26160 non-null  float64
#  23  totalpctsold            90750 non-null  float64
#  24  cobal                   90750 non-null  float64
#  25  credlimitclatresamt     90750 non-null  float64
#  26  riskratingcd            1873 non-null   object
#  27  origdate                25847 non-null  datetime64[ns]
#  28  currterm                26160 non-null  float64
#  29  loanidx                 26149 non-null  object
#  30  rcf                     2780 non-null   object
#  31  availbalamt             90750 non-null  float64
#  32  fdiccatdesc             25364 non-null  object
#  33  origbal                 24880 non-null  float64
#  34  loanlimityn             26160 non-null  object
#  35  Net Balance             90750 non-null  float64
#  36  Net Available           90750 non-null  float64
#  37  Net Collateral Reserve  90750 non-null  float64
#  38  Total Exposure          90750 non-null  float64
#  39  orig_ttl_loan_amt       90750 non-null  float64
#  40  portfolio_key           90743 non-null  float64
#  41  ownership_key           90743 non-null  float64
#  42  address_key             90743 non-null  float64
#  43  householdnbr            81652 non-null  float64
#  44  datelastmaint           81652 non-null  datetime64[ns]
#  45  Category                26160 non-null  object
#  46  inactivedate            2565 non-null   datetime64[ns]
# dtypes: datetime64[ns](6), float64(23), object(18)
# memory usage: 32.5+ MB
#          effdate    acctnbr                  ownersortname  \
# 0     2023-12-29  150200005  MONEYGRAM PAYMENT SYSTEMS INC
# 1     2023-12-29  150847394              COUNTY OF BRISTOL
# 2     2023-12-29  150887241                CITY OF TAUNTON
# 3     2023-12-29  150936915        REDBROOK APARTMENTS LLC
# 4     2023-12-29  150847401              COUNTY OF BRISTOL
# ...          ...        ...                            ...
# 90745 2023-12-29  150713503      CAPPO MANAGEMENT LII, LLC
# 90746 2023-12-29   27047636    BRISTOL COUNTY SAVINGS BANK
# 90747 2023-12-29   27039064    BRISTOL COUNTY SAVINGS BANK
# 90748 2023-12-29  150337783    BRISTOL COUNTY SAVINGS BANK
# 90749 2023-12-29   27020568    BRISTOL COUNTY SAVINGS BANK
#
#                         product  noteopenamt ratetypcd mjaccttypcd  \
# 0             Treasurer's Check          0.0      None        BKCK
# 1        Municipal Money Market          0.0       VAR          CK
# 2             ICS Shadow - Muni          0.0      None          CK
# 3          Commercial Mortgages   65500000.0       VAR         CML
# 4         15 Month Municipal CD          0.0       FIX          TD
# ...                         ...          ...       ...         ...
# 90745         Business Checking          0.0      None          CK
# 90746           Payoff Overages          0.0      None        BKCK
# 90747  Escrow Checks Processing          0.0      None        BKCK
# 90748         Business Checking          0.0      None          CK
# 90749          PDO Checks - OLD          0.0      None        BKCK
#
#       currmiaccttypcd curracctstatcd  noteintrate  ...  portfolio_key  \
# 0                TRCK            ACT     0.000000  ...        41516.0
# 1                CK18            ACT     0.037500  ...         4205.0
# 2                CK36            ACT     0.000000  ...         4183.0
# 3                CM40            ACT     0.075959  ...        57113.0
# 4                CD85            ACT     0.042500  ...         4205.0
# ...               ...            ...          ...  ...            ...
# 90745            CK12            ACT     0.000000  ...        65487.0
# 90746            BTC2            ACT     0.000000  ...         1221.0
# 90747            BTC3            ACT     0.000000  ...         1221.0
# 90748            CK12            ACT     0.000000  ...         1221.0
# 90749            BTC1            ACT     0.000000  ...         1221.0
#
#        ownership_key address_key householdnbr       datelastmaint  Category  \
# 0            43261.0     44260.0     187340.0 2020-02-26 23:28:03       NaN
# 1             4427.0      4671.0          NaN                 NaT       NaN
# 2            33668.0     33967.0          NaN                 NaT       NaN
# 3            59661.0     61147.0     193906.0 2023-09-22 08:01:38       CRE
# 4             4427.0      4671.0          NaN                 NaT       NaN
# ...              ...         ...          ...                 ...       ...
# 90745        68575.0     70249.0     241811.0 2022-02-25 22:36:05       NaN
# 90746         1352.0     41645.0     255924.0 2022-09-27 22:46:27       NaN
# 90747         1352.0     41577.0     255924.0 2022-09-27 22:46:27       NaN
# 90748         1352.0     51094.0     255924.0 2022-09-27 22:46:27       NaN
# 90749         1352.0     41437.0     255924.0 2022-09-27 22:46:27       NaN
#
#       inactivedate                      branchname  primaryownercity  \
# 0              NaT              BCSB - MAIN OFFICE       MINNEAPOLIS
# 1              NaT         BCSB - MUNI MAIN OFFICE           TAUNTON
# 2              NaT         BCSB - MUNI MAIN OFFICE           TAUNTON
# 3              NaT  BCSB - COMM'L LENDING- TAUNTON         BRAINTREE
# 4              NaT         BCSB - MUNI MAIN OFFICE           TAUNTON
# ...            ...                             ...               ...
# 90745          NaT     BCSB - NORTH RAYNHAM BRANCH          BROCKTON
# 90746          NaT              BCSB - MAIN OFFICE           TAUNTON
# 90747          NaT              BCSB - MAIN OFFICE           TAUNTON
# 90748          NaT              BCSB - MAIN OFFICE           TAUNTON
# 90749          NaT              BCSB - MAIN OFFICE           TAUNTON
#
#       primaryownerstate
# 0                    MN
# 1                    MA
# 2                    MA
# 3                    MA
# 4                    MA
# ...                 ...
# 90745                MA
# 90746                MA
# 90747                MA
# 90748                MA
# 90749                MA
#
# [90750 rows x 50 columns]

# %%
specified_date = datetime(2024, 12, 31)
data2024 = query_df_on_date(specified_date)
data2024
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90812 entries, 0 to 90811
# Data columns (total 47 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   effdate                 90812 non-null  datetime64[ns]
#  1   acctnbr                 90812 non-null  object
#  2   ownersortname           90812 non-null  object
#  3   product                 90812 non-null  object
#  4   noteopenamt             90812 non-null  float64
#  5   ratetypcd               72843 non-null  object
#  6   mjaccttypcd             90812 non-null  object
#  7   currmiaccttypcd         90812 non-null  object
#  8   curracctstatcd          90812 non-null  object
#  9   noteintrate             90812 non-null  float64
#  10  bookbalance             90812 non-null  float64
#  11  notebal                 90812 non-null  float64
#  12  contractdate            90811 non-null  datetime64[ns]
#  13  datemat                 34195 non-null  datetime64[ns]
#  14  taxrptfororgnbr         12126 non-null  float64
#  15  taxrptforpersnbr        78686 non-null  float64
#  16  loanofficer             24432 non-null  object
#  17  acctofficer             62800 non-null  object
#  18  creditlimitamt          90812 non-null  float64
#  19  origintrate             23781 non-null  object
#  20  marginfixed             24433 non-null  object
#  21  fdiccatcd               23836 non-null  object
#  22  amortterm               24433 non-null  float64
#  23  totalpctsold            90812 non-null  float64
#  24  cobal                   90812 non-null  float64
#  25  credlimitclatresamt     90812 non-null  float64
#  26  riskratingcd            2742 non-null   object
#  27  origdate                24238 non-null  datetime64[ns]
#  28  currterm                24433 non-null  float64
#  29  loanidx                 24421 non-null  object
#  30  rcf                     2890 non-null   object
#  31  availbalamt             90812 non-null  float64
#  32  fdiccatdesc             23836 non-null  object
#  33  origbal                 23499 non-null  float64
#  34  loanlimityn             24433 non-null  object
#  35  Net Balance             90812 non-null  float64
#  36  Net Available           90812 non-null  float64
#  37  Net Collateral Reserve  90812 non-null  float64
#  38  Total Exposure          90812 non-null  float64
#  39  orig_ttl_loan_amt       90812 non-null  float64
#  40  portfolio_key           90812 non-null  int64
#  41  ownership_key           90812 non-null  int64
#  42  address_key             90812 non-null  int64
#  43  householdnbr            81343 non-null  float64
#  44  datelastmaint           81343 non-null  datetime64[ns]
#  45  Category                24433 non-null  object
#  46  inactivedate            2446 non-null   datetime64[ns]
# dtypes: datetime64[ns](6), float64(20), int64(3), object(18)
# memory usage: 32.6+ MB
#          effdate    acctnbr                  ownersortname  \
# 0     2024-12-31  150200005  MONEYGRAM PAYMENT SYSTEMS INC
# 1     2024-12-31  150586025       GREATER FALL RIVER V.S.D
# 2     2024-12-31  150936915        REDBROOK APARTMENTS LLC
# 3     2024-12-31  150847394              COUNTY OF BRISTOL
# 4     2024-12-31  151058057             NBPIV SARATOGA LLC
# ...          ...        ...                            ...
# 90807 2024-12-31   27047237     FIRST AUTOMOTIVE GROUP INC
# 90808 2024-12-31  151116235                   FTRF 143 INC
# 90809 2024-12-31   27039064    BRISTOL COUNTY SAVINGS BANK
# 90810 2024-12-31   27020568    BRISTOL COUNTY SAVINGS BANK
# 90811 2024-12-31  150337783    BRISTOL COUNTY SAVINGS BANK
#
#                         product  noteopenamt ratetypcd mjaccttypcd  \
# 0             Treasurer's Check          0.0      None        BKCK
# 1                 Municipal Now          0.0       VAR          CK
# 2          Commercial Mortgages   65500000.0       VAR         CML
# 3        Municipal Money Market          0.0       VAR          CK
# 4          Commercial Mortgages   26000000.0       FIX         CML
# ...                         ...          ...       ...         ...
# 90807         Business Checking          0.0      None          CK
# 90808  Simple Business Checking        500.0      None          CK
# 90809  Escrow Checks Processing          0.0      None        BKCK
# 90810          PDO Checks - OLD          0.0      None        BKCK
# 90811         Business Checking          0.0      None          CK
#
#       currmiaccttypcd curracctstatcd  noteintrate  ...  portfolio_key  \
# 0                TRCK            ACT     0.000000  ...          41516
# 1                CK27            ACT     0.000300  ...          40677
# 2                CM40            ACT     0.067809  ...          57113
# 3                CK18            ACT     0.035000  ...           4205
# 4                CM40            ACT     0.063500  ...          79216
# ...               ...            ...          ...  ...            ...
# 90807            CK12            ACT     0.000000  ...           3730
# 90808            CK25            ACT     0.000000  ...          81398
# 90809            BTC3            ACT     0.000000  ...           1221
# 90810            BTC1            ACT     0.000000  ...           1221
# 90811            CK12            ACT     0.000000  ...           1221
#
#        ownership_key address_key householdnbr       datelastmaint  Category  \
# 0              43261       44260     187340.0 2020-02-26 23:28:03       NaN
# 1              42158       43236     185474.0 2021-03-25 22:19:28       NaN
# 2              59661       61147     193906.0 2023-09-22 08:01:38       CRE
# 3               4427        4671          NaN                 NaT       NaN
# 4              83546       85431     288455.0 2024-06-11 12:02:04       CRE
# ...              ...         ...          ...                 ...       ...
# 90807           3935       41292     188829.0 2023-10-19 11:11:11       NaN
# 90808          85988       87850     296485.0 2024-12-16 20:42:14       NaN
# 90809           1352       41577     255924.0 2022-09-27 22:46:27       NaN
# 90810           1352       41437     255924.0 2022-09-27 22:46:27       NaN
# 90811           1352       51094     255924.0 2022-09-27 22:46:27       NaN
#
#       inactivedate                      branchname  primaryownercity  \
# 0              NaT              BCSB - MAIN OFFICE       MINNEAPOLIS
# 1              NaT   BCSB - MUNI FALL RIVER BRANCH        FALL RIVER
# 2              NaT  BCSB - COMM'L LENDING- TAUNTON         BRAINTREE
# 3              NaT         BCSB - MUNI MAIN OFFICE           TAUNTON
# 4              NaT  BCSB - COMM'L LENDING- TAUNTON         WAKEFIELD
# ...            ...                             ...               ...
# 90807          NaT              BCSB - MAIN OFFICE   NORTH ATTLEBORO
# 90808          NaT       BCSB - CANDLEWORKS BRANCH      EAST WAREHAM
# 90809          NaT              BCSB - MAIN OFFICE           TAUNTON
# 90810          NaT              BCSB - MAIN OFFICE           TAUNTON
# 90811          NaT              BCSB - MAIN OFFICE           TAUNTON
#
#       primaryownerstate
# 0                    MN
# 1                    MA
# 2                    MA
# 3                    MA
# 4                    MA
# ...                 ...
# 90807                MA
# 90808                MA
# 90809                MA
# 90810                MA
# 90811                MA
#
# [90812 rows x 50 columns]

# %%
def get_deposit_totals(df):
    df = df[df['mjaccttypcd'].isin(['CK','SAV','TD'])].copy()
    sum = df['Net Balance'].sum()
    return sum

# %%
sum2020 = get_deposit_totals(data2020)

# %%
f"{sum2020:,.2f}"
# Out:
# '2,283,515,795.77'

# %%
sum2021 = get_deposit_totals(data2021)

# %%
sum2022 = get_deposit_totals(data2022)
sum2023 = get_deposit_totals(data2023)
sum2024 = get_deposit_totals(data2024)

# %%
print(f"2020: {sum2020:,.2f}")
print(f"2021: {sum2021:,.2f}")
print(f"2022: {sum2022:,.2f}")
print(f"2023: {sum2023:,.2f}")
print(f"2024: {sum2024:,.2f}")
# Out:
# 2020: 2,283,515,795.77
# 2021: 2,513,328,664.16
# 2022: 2,400,121,111.40
# 2023: 2,451,179,978.56
# 2024: 2,509,165,954.44

# %%
data = fetch_data()

# %%
wh_addr = data['wh_addr'].copy()
orgaddruse = data['orgaddruse'].copy()

# %%
persaddruse = data['persaddruse'].copy()

# %%
wh_addr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 376318 entries, 0 to 376317
# Data columns (total 57 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   addrnbr           376318 non-null  int64
#  1   linenbr           376318 non-null  int64
#  2   rundate           376318 non-null  datetime64[ns]
#  3   ctrycd            376318 non-null  object
#  4   nextlinenbr       376318 non-null  int64
#  5   ctrysubdivcd      138 non-null     object
#  6   ctrymailcd        2473 non-null    object
#  7   statecd           269156 non-null  object
#  8   cityname          376318 non-null  object
#  9   citynamesndx      301400 non-null  object
#  10  zipcd             269133 non-null  object
#  11  zipsuf            205936 non-null  object
#  12  censustrtnbr      5503 non-null    object
#  13  smsanbr           5405 non-null    object
#  14  postnetcd         182834 non-null  object
#  15  addrlinetypcd1    376297 non-null  object
#  16  text1             376297 non-null  object
#  17  addrlinetypdesc1  376297 non-null  object
#  18  addrlinetypseq1   376297 non-null  float64
#  19  addrtextsndx1     301247 non-null  object
#  20  addrlinetypcd2    9488 non-null    object
#  21  text2             9488 non-null    object
#  22  addrlinetypdesc2  9488 non-null    object
#  23  addrlinetypseq2   9488 non-null    float64
#  24  addrtextsndx2     4420 non-null    object
#  25  addrlinetypcd3    393 non-null     object
#  26  text3             393 non-null     object
#  27  addrlinetypdesc3  393 non-null     object
#  28  addrlinetypseq3   393 non-null     float64
#  29  addrtextsndx3     369 non-null     object
#  30  addrlinetypcd4    2 non-null       object
#  31  text4             2 non-null       object
#  32  addrlinetypdesc4  2 non-null       object
#  33  addrlinetypseq4   2 non-null       float64
#  34  addrtextsndx4     2 non-null       object
#  35  addrlinetypcd5    0 non-null       object
#  36  text5             0 non-null       object
#  37  addrlinetypdesc5  0 non-null       object
#  38  addrlinetypseq5   0 non-null       object
#  39  addrtextsndx5     0 non-null       object
#  40  addrlinetypcd6    0 non-null       object
#  41  text6             0 non-null       object
#  42  addrlinetypdesc6  0 non-null       object
#  43  addrlinetypseq6   0 non-null       object
#  44  addrtextsndx6     0 non-null       object
#  45  addrlinetypcd7    0 non-null       object
#  46  text7             0 non-null       object
#  47  addrlinetypdesc7  0 non-null       object
#  48  addrlinetypseq7   0 non-null       object
#  49  addrtextsndx7     0 non-null       object
#  50  mailaddryn        376318 non-null  object
#  51  mailtypcd         0 non-null       object
#  52  mailtypdesc       0 non-null       object
#  53  addrusecd         362762 non-null  object
#  54  addrusedesc       362762 non-null  object
#  55  electronicyn      376318 non-null  object
#  56  datelastmaint     376318 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(4), int64(3), object(48)
# memory usage: 163.7+ MB

# %%
wh_addr
# Out:
#         addrnbr  linenbr    rundate ctrycd  nextlinenbr ctrysubdivcd  \
# 0       1004857        1 2025-07-15    USA            2         None
# 1       1004858        1 2025-07-15    USA            2         None
# 2       1004859        1 2025-07-15    USA            2         None
# 3       1004860        1 2025-07-15    USA            2         None
# 4       1004861        1 2025-07-15    USA            2         None
# ...         ...      ...        ...    ...          ...          ...
# 376313  1432363        1 2025-07-15    USA            2         None
# 376314  1432364        1 2025-07-15    USA            2         None
# 376315  1432368        1 2025-07-15    USA            2         None
# 376316  1432370        1 2025-07-15    USA            2         None
# 376317  1432383        1 2025-07-15    USA            2         None
#
#        ctrymailcd statecd          cityname citynamesndx  ...  \
# 0            None      MA       NEWBURYPORT         N161  ...
# 1            None      MA        FALL RIVER         F461  ...
# 2            None      MA  WEST HYANNISPORT         W235  ...
# 3            None      MA         MANSFIELD         M521  ...
# 4            None      MA          ROCKLAND         R245  ...
# ...           ...     ...               ...          ...  ...
# 376313       None    None             EMAIL         E540  ...
# 376314       None      RI           LINCOLN         L524  ...
# 376315       None      MA      EAST WALPOLE         None  ...
# 376316       None      MA     EAST FREETOWN         None  ...
# 376317       None    None                           None  ...
#
#        addrlinetypdesc7 addrlinetypseq7 addrtextsndx7 mailaddryn mailtypcd  \
# 0                  None            None          None          Y      None
# 1                  None            None          None          Y      None
# 2                  None            None          None          Y      None
# 3                  None            None          None          Y      None
# 4                  None            None          None          Y      None
# ...                 ...             ...           ...        ...       ...
# 376313             None            None          None          Y      None
# 376314             None            None          None          Y      None
# 376315             None            None          None          Y      None
# 376316             None            None          None          Y      None
# 376317             None            None          None          Y      None
#
#        mailtypdesc addrusecd             addrusedesc  electronicyn  \
# 0             None       RES             Residential             N
# 1             None       RES             Residential             N
# 2             None       RES             Residential             N
# 3             None       RES             Residential             N
# 4             None       PRI                 Primary             N
# ...            ...       ...                     ...           ...
# 376313        None      HEML      Home Email Address             Y
# 376314        None      None                    None             N
# 376315        None       PRI                 Primary             N
# 376316        None       PRI                 Primary             N
# 376317        None      EMAL  Business Email Address             Y
#
#              datelastmaint
# 0      2025-07-15 21:33:45
# 1      2025-07-15 21:33:45
# 2      2025-07-15 21:33:45
# 3      2025-07-15 21:33:45
# 4      2025-07-15 21:33:45
# ...                    ...
# 376313 2025-07-15 21:34:37
# 376314 2025-07-15 21:34:37
# 376315 2025-07-15 21:34:37
# 376316 2025-07-15 21:34:37
# 376317 2025-07-15 21:34:37
#
# [376318 rows x 57 columns]

# %%
persaddruse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 328697 entries, 0 to 328696
# Data columns (total 13 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   persnbr        328697 non-null  int64
#  1   addrusecd      328697 non-null  object
#  2   addrnbr        328697 non-null  int64
#  3   startdate      101 non-null     datetime64[ns]
#  4   stopdate       94 non-null      datetime64[ns]
#  5   inactivedate   0 non-null       object
#  6   effdate        328697 non-null  datetime64[ns]
#  7   occupancydate  0 non-null       object
#  8   startmonthcd   35 non-null      object
#  9   startdaynbr    35 non-null      float64
#  10  stopmonthcd    35 non-null      object
#  11  stopdaynbr     35 non-null      float64
#  12  datelastmaint  328697 non-null  datetime64[ns]
# dtypes: datetime64[ns](4), float64(2), int64(2), object(5)
# memory usage: 32.6+ MB

# %%
orgaddruse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34065 entries, 0 to 34064
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   orgnbr         34065 non-null  int64
#  1   addrusecd      34065 non-null  object
#  2   addrnbr        34065 non-null  int64
#  3   startdate      6 non-null      datetime64[ns]
#  4   stopdate       5 non-null      datetime64[ns]
#  5   inactivedate   0 non-null      object
#  6   effdate        34065 non-null  datetime64[ns]
#  7   occupancydate  0 non-null      object
#  8   startmonthcd   2 non-null      object
#  9   startdaynbr    2 non-null      float64
#  10  stopmonthcd    2 non-null      object
#  11  stopdaynbr     2 non-null      float64
#  12  datelastmaint  34065 non-null  datetime64[ns]
# dtypes: datetime64[ns](4), float64(2), int64(2), object(5)
# memory usage: 3.4+ MB
