# %%
import pandas as pd # type: ignore
from pathlib import Path
import src.transformations.joining
import src.cdutils.database
import src.cdutils.caching
import src.transformations.calculations

# Fetch data from database
data  = src.cdutils.database.fetch_data()

# Unpack data
wh_acctcommon = data['wh_acctcommon'].copy()
wh_acctloan = data['wh_acctloan'].copy()
wh_loans = data['wh_loans'].copy()
acctpropins = data['acctpropins'].copy()
wh_prop = data['wh_prop'].copy()
wh_prop2 = data['wh_prop2'].copy()
wh_inspolicy = data['wh_inspolicy'].copy()
persaddruse = data['persaddruse'].copy()
orgaddruse = data['orgaddruse'].copy()
wh_addr = data['wh_addr'].copy()

# Data Cleaning & Transformations
main_data = src.transformations.joining.join_loan_tables(wh_acctcommon, wh_acctloan, wh_loans)
prop_data = src.transformations.joining.join_prop_tables(wh_prop, wh_prop2)
main_data = src.transformations.joining.appending_owner_address(main_data, orgaddruse, persaddruse, wh_addr)
main_data = src.transformations.calculations.append_total_exposure_field(main_data)
main_data = src.transformations.calculations.cleaning_loan_data(main_data)
merged_data = src.transformations.joining.consolidation_with_multiple_props(main_data, prop_data)
insurance_merged = src.transformations.joining.merging_insurance_tables(acctpropins, wh_inspolicy)
merged_data = src.transformations.joining.append_insurance_data_to_main(merged_data, insurance_merged)

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9966 entries, 0 to 9965
# Data columns (total 78 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   acctnbr                 9966 non-null   int64
#  1   effdate                 9966 non-null   datetime64[ns]
#  2   ownersortname           9966 non-null   object
#  3   notebal                 9966 non-null   float64
#  4   bookbalance             9966 non-null   float64
#  5   mjaccttypcd             9966 non-null   object
#  6   currmiaccttypcd         9966 non-null   object
#  7   product                 9966 non-null   object
#  8   curracctstatcd          9966 non-null   object
#  9   taxrptforpersnbr        6193 non-null   float64
#  10  taxrptfororgnbr         3773 non-null   float64
#  11  loanofficer             9966 non-null   object
#  12  acctofficer             0 non-null      object
#  13  contractdate            9966 non-null   datetime64[ns]
#  14  noteopenamt             9966 non-null   float64
#  15  noteintrate             9966 non-null   float64
#  16  creditlimitamt          9966 non-null   float64
#  17  origintrate             9932 non-null   object
#  18  marginfixed             9966 non-null   object
#  19  fdiccatcd               9957 non-null   object
#  20  amortterm               9966 non-null   int64
#  21  totalpctsold            9966 non-null   float64
#  22  cobal                   9966 non-null   float64
#  23  credlimitclatresamt     9966 non-null   float64
#  24  origdate                9960 non-null   datetime64[ns]
#  25  currterm                9966 non-null   int64
#  26  loanidx                 9966 non-null   object
#  27  rcf                     4102 non-null   object
#  28  availbalamt             9966 non-null   float64
#  29  fdiccatdesc             9957 non-null   object
#  30  addrnbr                 9943 non-null   float64
#  31  text1                   9943 non-null   object
#  32  text2                   143 non-null    object
#  33  text3                   2 non-null      object
#  34  cityname                9943 non-null   object
#  35  statecd                 9943 non-null   object
#  36  zipcd                   9943 non-null   object
#  37  Net Balance             9966 non-null   float64
#  38  Net Available           9966 non-null   float64
#  39  Net Collateral Reserve  9966 non-null   float64
#  40  Total Exposure          9966 non-null   float64
#  41  orig_ttl_loan_amt       9966 non-null   float64
#  42  propnbr                 9939 non-null   float64
#  43  propaddr1               7494 non-null   object
#  44  propaddr2               12 non-null     object
#  45  propcity                7495 non-null   object
#  46  propstate               7493 non-null   object
#  47  propzip                 7482 non-null   object
#  48  aprsvalueamt            6973 non-null   object
#  49  aprsdate                6973 non-null   datetime64[ns]
#  50  proptypdesc             9939 non-null   object
#  51  propdesc                9922 non-null   object
#  52  intrpolicynbr           4477 non-null   float64
#  53  effdate_x               4477 non-null   datetime64[ns]
#  54  inactivedate_x          2 non-null      datetime64[ns]
#  55  datelastmaint_x         4477 non-null   datetime64[ns]
#  56  escrowyn                4477 non-null   object
#  57  lenderfundedyn          4477 non-null   object
#  58  escdisbchangeeffdate    3815 non-null   datetime64[ns]
#  59  rundate                 4477 non-null   datetime64[ns]
#  60  insorgnbr               4477 non-null   float64
#  61  instypcd                4477 non-null   object
#  62  extpolicynbr            4477 non-null   object
#  63  agentorgnbr             4 non-null      float64
#  64  premcalperiodcd         4472 non-null   object
#  65  premamt                 4472 non-null   object
#  66  effdate_y               4477 non-null   datetime64[ns]
#  67  expiredate              4353 non-null   datetime64[ns]
#  68  policydocnbr            0 non-null      object
#  69  inactivedate_y          1187 non-null   datetime64[ns]
#  70  firstmonthcd            4112 non-null   object
#  71  duedaynbr               4472 non-null   float64
#  72  dueweekdaycd            0 non-null      object
#  73  coverageamt             4382 non-null   object
#  74  firstyearnbr            0 non-null      object
#  75  refundableyn            4477 non-null   object
#  76  instypdesc              4477 non-null   object
#  77  datelastmaint_y         4477 non-null   datetime64[ns]
# dtypes: datetime64[ns](13), float64(22), int64(3), object(40)
# memory usage: 5.9+ MB

# %%
def filtering_down_to_relevant_fields(df: pd.DataFrame) -> pd.DataFrame:
    """
    Reducing total columns down to ones requested

    Args:
        df (pd.DataFrame)

    Returns
        df (pd.DataFrame): Same dataset, just reduced total columns
    """
    df = df[[
        'acctnbr',
        'ownersortname',
        'text1',
        'text2',
        'cityname',
        'statecd',
        'zipcd',
        'notebal',
        'creditlimitamt',
        'origdate',
        'proptypdesc',
        'propdesc',
        'propaddr1',
        'propaddr2',
        'propcity',
        'propstate',
        'propzip',
        'instypcd',
        'instypdesc',
        'coverageamt',
        'premamt',
        'escrowyn',
        'mjaccttypcd',
        'currmiaccttypcd',
        'fdiccatcd',
        'fdiccatdesc'
        ]].copy()
    
    return df

# %%
merged_data = filtering_down_to_relevant_fields(merged_data)
