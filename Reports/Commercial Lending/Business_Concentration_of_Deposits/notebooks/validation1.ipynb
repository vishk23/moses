# %%
import os
import sys
from pathlib import Path

# Navigate to project root (equivalent to cd ..)
project_dir = Path(__file__).parent.parent if '__file__' in globals() else Path.cwd().parent
os.chdir(project_dir)

# Add src directory to Python path for imports
src_dir = project_dir / "src"
if str(src_dir) not in sys.path:
    sys.path.insert(0, str(src_dir))

# Set environment for dev testing
os.environ['REPORT_ENV'] = 'dev'

# %%
import pandas as pd

# %%
XAA_PATH = Path(r"C:\Users\w322800\Documents\gh\bcsb-prod\Reports\Commercial Lending\Business_Concentration_of_Deposits\input\PxV Fee Income Report_Jun2024-July2025.csv")
xaa = pd.read_csv(XAA_PATH)

# %%
xaa
# Out:
#       Cycle End Date  Analysis Account Type Application ID  \
# 0          6/30/2025                     13              C
# 1          6/30/2024                     12              C
# 2          7/31/2024                     12              C
# 3          8/31/2024                     13              C
# 4          9/30/2024                     13              C
# ...              ...                    ...            ...
# 62291      7/31/2025                     25              D
# 62292      7/31/2025                     25              D
# 62293      7/31/2025                     25              D
# 62294      7/31/2025                     25              D
# 62295      7/31/2025                     25              D
#
#                    Account Name  Debit Account Number  \
# 0      YOUNG MEN'S CHRISTIAN AS              24703748
# 1      YOUNG MEN'S CHRISTIAN AS              24703748
# 2      YOUNG MEN'S CHRISTIAN AS              24703748
# ...

# %%
xaa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62296 entries, 0 to 62295
# Data columns (total 14 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Cycle End Date                                    62296 non-null  object
#  1   Analysis Account Type                             62296 non-null  int64
#  2   Application ID                                    62296 non-null  object
#  3   Account Name                                      62296 non-null  object
#  4   Debit Account Number                              62296 non-null  int64
#  5   Analyzed Charges (Pre-ECR)                        62296 non-null  object
#  6   Earnings Credit Rate                              62296 non-null  float64
#  7   Earnings Credit Amount                            62296 non-null  object
#  8   Analyzed Result Month-to-Date (Post-ECR)          62296 non-null  object
# ...

# %%
xaa['Cycle End Date'] = pd.to_datetime(xaa['Cycle End Date'])

# %%
xaa
# Out:
#       Cycle End Date  Analysis Account Type Application ID  \
# 0         2025-06-30                     13              C
# 1         2024-06-30                     12              C
# 2         2024-07-31                     12              C
# 3         2024-08-31                     13              C
# 4         2024-09-30                     13              C
# ...              ...                    ...            ...
# 62291     2025-07-31                     25              D
# 62292     2025-07-31                     25              D
# 62293     2025-07-31                     25              D
# 62294     2025-07-31                     25              D
# 62295     2025-07-31                     25              D
#
#                    Account Name  Debit Account Number  \
# 0      YOUNG MEN'S CHRISTIAN AS              24703748
# 1      YOUNG MEN'S CHRISTIAN AS              24703748
# 2      YOUNG MEN'S CHRISTIAN AS              24703748
# ...

# %%
df_sorted = xaa.sort_values(by='Cycle End Date', ascending=False)

df_deduped = df_sorted.drop_duplicates(subset='Debit Account Number', keep='first').copy()
df_deduped['Combined Result for Settlement Period (Post-ECR)'] = df_deduped['Combined Result for Settlement Period (Post-ECR)'].str.replace(r'[$,]', '', regex=True)
df_deduped['Combined Result for Settlement Period (Post-ECR)'] = pd.to_numeric(df_deduped['Combined Result for Settlement Period (Post-ECR)'])
total_sum = df_deduped['Combined Result for Settlement Period (Post-ECR)'].sum()
total_sum
# Out:
# np.float64(63146.990000000005)
