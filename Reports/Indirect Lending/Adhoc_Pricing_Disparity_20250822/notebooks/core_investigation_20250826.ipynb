# %%
import os
import sys
from pathlib import Path

# Navigate to project root (equivalent to cd ..)
project_dir = Path(__file__).parent.parent if '__file__' in globals() else Path.cwd().parent
os.chdir(project_dir)

# Add src directory to Python path for imports
src_dir = project_dir / "src"
if str(src_dir) not in sys.path:
    sys.path.insert(0, str(src_dir))

# Set environment for dev testing
os.environ['REPORT_ENV'] = 'dev'

# %%
import src.account_data_adhoc.core
# Out:
# Proof running correct one

# %%
df = src.account_data_adhoc.core.query_df_on_date()

# %%
df
# Out:
#          effdate    acctnbr               ownersortname  \
# 0     2025-08-25  150586025    GREATER FALL RIVER V.S.D
# 1     2025-08-25  150887241             CITY OF TAUNTON
# 2     2025-08-25  151058057          NBPIV SARATOGA LLC
# 3     2025-08-25  150862011     R3 PROJECT COMPANY, LLC
# 4     2025-08-25  151038843              POWER 250, LLC
# ...          ...        ...                         ...
# 68020 2025-08-25  150914333        BROUGHEY, MICHAEL H.
# 68021 2025-08-25  151104321        LADOUCEUR, CHERYL A.
# 68022 2025-08-25  150973701           BULCAO, ANDREA F.
# 68023 2025-08-25  151141810          RODRIGUEZ, JASMINE
# 68024 2025-08-25  150640011  HEIDREA COMMUNICATIONS LLC
#
#                             product  noteopenamt ratetypcd mjaccttypcd  \
# 0                     Municipal Now         0.00       VAR          CK
# 1      ICS Shadow - Muni - MMDA/SAV         0.00      None          CK
# 2              Commercial Mortgages  26000000.00       FIX         CML
# 3            CML Fixed Construction  20000000.00       FIX         CML
# 4              CML ARM Construction  27500000.00       VAR         CML
# ...                             ...          ...       ...         ...
# 68020         eChecking (18 & over)      1643.27      None          CK
# 68021                  NOW Checking     12149.95       VAR          CK
# 68022           Prime Time Checking        10.00       VAR          CK
# 68023         eChecking (18 & over)    114874.59      None          CK
# 68024             Business Checking      3333.00      None          CK
#
#       currmiaccttypcd curracctstatcd  noteintrate  ...  portfolio_key  \
# 0                CK27            ACT     0.000300  ...          40673
# 1                CK42            ACT     0.000000  ...           4183
# 2                CM40            ACT     0.063500  ...          79204
# 3                CM07            ACT     0.065000  ...          72247
# 4                CM08            ACT     0.070811  ...          44088
# ...               ...            ...          ...  ...            ...
# 68020            CK04            ACT     0.000000  ...          74265
# 68021            CK05            ACT     0.000300  ...          80976
# 68022            CK06            ACT     0.000300  ...          76489
# 68023            CK04            ACT     0.000000  ...          82109
# 68024            CK12            ACT     0.000000  ...           3774
#
#        ownership_key address_key householdnbr       datelastmaint  Category  \
# 0            42158.0     43236.0     185474.0 2021-03-25 22:19:28       NaN
# 1            33668.0     33967.0          NaN                 NaT       NaN
# 2            83546.0     85431.0     288455.0 2024-06-11 12:02:04       CRE
# 3            75826.0     77677.0     264869.0 2023-03-13 22:23:21       CRE
# 4            45945.0     47063.0     134214.0 2024-04-24 15:47:27       CRE
# ...              ...         ...          ...                 ...       ...
# 68020        78029.0     79911.0          NaN                 NaT       NaN
# 68021        85511.0     87392.0     273827.0 2024-09-25 20:44:12       NaN
# 68022        80481.0     82405.0     105758.0 2023-11-15 22:31:58       NaN
# 68023        86812.0     88705.0     304472.0 2025-01-24 20:34:13       NaN
# 68024         3981.0      4162.0     185650.0 2021-09-14 13:35:26       NaN
#
#        inactivedate                       branchname primaryownercity  \
# 0               NaT    BCSB - MUNI FALL RIVER BRANCH       FALL RIVER
# 1               NaT          BCSB - MUNI MAIN OFFICE          TAUNTON
# 2               NaT   BCSB - COMM'L LENDING- TAUNTON        WAKEFIELD
# 3        2026-03-07   BCSB - COMM'L LENDING- TAUNTON           QUINCY
# 4        2026-10-22  BCSB - COMM'L LENDING - WARWICK     EAST WALPOLE
# ...             ...                              ...              ...
# 68020           NaT               BCSB - MAIN OFFICE          TAUNTON
# 68021           NaT          BCSB - ATTLEBORO BRANCH        ATTLEBORO
# 68022           NaT         BCSB - FALL RIVER BRANCH       FALL RIVER
# 68023           NaT               BCSB - MAIN OFFICE          TAUNTON
# 68024           NaT           BCSB - FRANKLIN BRANCH       BELLINGHAM
#
#        primaryownerstate
# 0                     MA
# 1                     MA
# 2                     MA
# 3                     MA
# 4                     MA
# ...                  ...
# 68020                 MA
# 68021                 MA
# 68022                 MA
# 68023                 MA
# 68024                 MA
#
# [68025 rows x 52 columns]

# %%
indirect_current = df[(df['Category'].isin(['Indirect'])) | (df['currmiaccttypcd']).isin(['CM15','CM16'])].copy()

# %%
indirect_current['product'].unique()
# Out:
# array(['New Indirect Auto', 'Used Indirect Auto', 'Indirect New Business',
#        'Indirect Used Business', 'Used Indirect Motorcycle',
#        'New Indirect Motorcycle', 'Classic Indirect Auto',
#        'BCSB Auto Used', 'Repossessed Collateral'], dtype=object)

# %%
indirect_current
# Out:
#          effdate    acctnbr          ownersortname                product  \
# 4980  2025-08-25  151064567   SITCOSKE, MATTHEW P.      New Indirect Auto
# 5754  2025-08-25  151198093    RINALDI, MATTHEW D.      New Indirect Auto
# 5945  2025-08-25  151127365     RICCI, LIBERATO G.     Used Indirect Auto
# 6054  2025-08-25  151211069      THORNTON, RORY P.     Used Indirect Auto
# 6060  2025-08-25  151157750     PAIVA, LOUIS M. II      New Indirect Auto
# ...          ...        ...                    ...                    ...
# 67657 2025-08-25     254665     TOOLS FOR BUILDING         BCSB Auto Used
# 67774 2025-08-25      45978    GARRETT, PHILLIP S.     Used Indirect Auto
# 67782 2025-08-25   50480938       KANAGA II, GLENN  Classic Indirect Auto
# 67783 2025-08-25   50550616  MCKIERNAN, MICHAEL A.     Used Indirect Auto
# 67785 2025-08-25      71033          JACOB, BONNIE     Used Indirect Auto
#
#        noteopenamt ratetypcd mjaccttypcd currmiaccttypcd curracctstatcd  \
# 4980     136943.19       FIX         CNS            IL11            ACT
# 5754      99991.15       FIX         CNS            IL11            ACT
# 5945      97581.85       FIX         CNS            IL12            ACT
# 6054      86983.26       FIX         CNS            IL12            ACT
# 6060      92159.73       FIX         CNS            IL11            ACT
# ...            ...       ...         ...             ...            ...
# 67657     15249.00       FIX         CNS            IL04            CLS
# 67774     32554.13       FIX         CNS            IL12            CLS
# 67782      8818.00       FIX         CNS            IL02            CLS
# 67783     30594.81       FIX         CNS            IL12            CLS
# 67785      7204.77       FIX         CNS            IL12            CLS
#
#        noteintrate  ...  portfolio_key  ownership_key address_key  \
# 4980        0.0699  ...          67775        70993.0     72719.0
# 5754        0.0589  ...          83956            NaN         NaN
# 5945        0.0854  ...          70101        73487.0     75291.0
# 6054        0.0534  ...          76141            NaN         NaN
# 6060        0.0544  ...          82668        87456.0     89336.0
# ...            ...  ...            ...            ...         ...
# 67657       0.0405  ...            979         1109.0      1079.0
# 67774       0.0254  ...             78           78.0        81.0
# 67782       0.0775  ...          40883        42425.0     43484.0
# 67783       0.0214  ...          40884        42426.0     43485.0
# 67785       0.0314  ...             79           79.0        82.0
#
#       householdnbr       datelastmaint  Category  inactivedate  \
# 4980           NaN                 NaT  Indirect           NaT
# 5754      324865.0 2025-06-30 21:00:53  Indirect           NaT
# 5945           NaN                 NaT  Indirect           NaT
# 6054      330045.0 2025-08-07 20:34:05  Indirect           NaT
# 6060      311661.0 2025-03-17 20:49:06  Indirect           NaT
# ...            ...                 ...       ...           ...
# 67657     201226.0 2020-09-01 22:33:25  Indirect           NaT
# 67774     199343.0 2020-08-05 22:34:57  Indirect           NaT
# 67782          NaN                 NaT  Indirect           NaT
# 67783     211738.0 2021-01-06 22:50:05  Indirect           NaT
# 67785     236397.0 2021-12-10 23:19:37  Indirect           NaT
#
#                     branchname primaryownercity  primaryownerstate
# 4980   BCSB - INDIRECT LENDING        RIVERSIDE                 RI
# 5754   BCSB - INDIRECT LENDING     SAUNDERSTOWN                 RI
# 5945   BCSB - INDIRECT LENDING         CRANSTON                 RI
# 6054   BCSB - INDIRECT LENDING       MIDDLEBORO                 MA
# 6060   BCSB - INDIRECT LENDING         CRANSTON                 RI
# ...                        ...              ...                ...
# 67657                      NaN              NaN                NaN
# 67774                      NaN              NaN                NaN
# 67782                      NaN              NaN                NaN
# 67783                      NaN              NaN                NaN
# 67785                      NaN              NaN                NaN
#
# [25473 rows x 52 columns]
