# %%
import os
import sys
from pathlib import Path

# Navigate to project root (equivalent to cd ..)
project_dir = Path(__file__).parent.parent if '__file__' in globals() else Path.cwd().parent
os.chdir(project_dir)

# Add src directory to Python path for imports
src_dir = project_dir / "src"
if str(src_dir) not in sys.path:
    sys.path.insert(0, str(src_dir))

# Set environment for dev testing
os.environ['REPORT_ENV'] = 'prod'

# %%
import cdutils.database.connect # type: ignore
from sqlalchemy import text # type: ignore
from datetime import datetime
from typing import Optional

# Define fetch data here using cdutils.database.connect
# There are often fetch_data.py files already in project if migrating
def fetch_data():
    """
    Gets data from COCC
    """
    acctloanlimithist = text("""
    SELECT 
        *
    FROM 
        OSIBANK.WH_ORGPERSROLE
    """)

    queries = [
        {'key':'acctloanlimithist', 'sql':acctloanlimithist, 'engine':1},
    ]

    data = cdutils.database.connect.retrieve_data(queries)
    return data

# %%
data = fetch_data()

# %%
df = data['acctloanlimithist'].copy()

# %%
df
# Out:
#         orgnbr    rundate persrolecd    persnbr         persroledesc  \
# 0      1016993 2025-10-08       DSIG  1059850.0    Designated Signor
# 1      1016541 2025-10-08       DSIG  1033542.0    Designated Signor
# 2      1016720 2025-10-08       DSIG  1172150.0    Designated Signor
# 3      1012271 2025-10-08       DSIG      355.0    Designated Signor
# 4      1018465 2025-10-08       DSIG  1174593.0    Designated Signor
# ...        ...        ...        ...        ...                  ...
# 13667  1003122 2025-10-08       TRSE  1075169.0  Treasurer/Secretary
# 13668  1004276 2025-10-08       TRSE  1071968.0  Treasurer/Secretary
# 13669  1012704 2025-10-08       TRSE  1132550.0  Treasurer/Secretary
# 13670  1017463 2025-10-08       TRSE  1048335.0  Treasurer/Secretary
# 13671  1002199 2025-10-08       TRSE  1154265.0  Treasurer/Secretary
#
#       orgrolecd  subjorgnbr orgroledesc       datelastmaint
# 0          None         NaN        None 2025-10-08 21:31:53
# 1          None         NaN        None 2025-10-08 21:31:53
# 2          None         NaN        None 2025-10-08 21:31:53
# 3          None         NaN        None 2025-10-08 21:31:53
# 4          None         NaN        None 2025-10-08 21:31:53
# ...         ...         ...         ...                 ...
# 13667      None         NaN        None 2025-10-08 21:31:53
# 13668      None         NaN        None 2025-10-08 21:31:53
# 13669      None         NaN        None 2025-10-08 21:31:53
# 13670      None         NaN        None 2025-10-08 21:31:53
# 13671      None         NaN        None 2025-10-08 21:31:53
#
# [13672 rows x 9 columns]

# %%
assert df['acctnbr'].is_unique, "Dupes"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 assert df['acctnbr'].is_unique, "Dupes"
#
# AssertionError: Dupes

# %%
df['invrstatcd'].unique()

# %%
assert df['acctnbr'].is_unique, "Fail"

# %%
import cdutils.database.connect # type: ignore
from sqlalchemy import text # type: ignore
from datetime import datetime
from typing import Optional

# Define fetch data here using cdutils.database.connect
# There are often fetch_data.py files already in project if migrating
def fetch_data():
    """
    Main data query
    """
    query = text("""
    SELECT
        *
    FROM
        OSIBANK.ACCTGRPINVR a
    """)    
    # vieworgtaxid = text(f"""
    # SELECT
    #     *
    # FROM
    #     OSIBANK.VIEWORGTAXID a
    # """)

    queries = [
        {'key':'query', 'sql':query, 'engine':1},
        
        # {'key':'vieworgtaxid', 'sql':vieworgtaxid, 'engine':1},
    ]


    data = cdutils.database.connect.retrieve_data(queries)
    return data

# %%
data = fetch_data()

# %%
df = data['query'].copy()

# %%
df
