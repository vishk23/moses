# %%
import os
import sys
from pathlib import Path

# Navigate to project root (equivalent to cd ..)
project_dir = Path(__file__).parent.parent if '__file__' in globals() else Path.cwd().parent
os.chdir(project_dir)

# Add src directory to Python path for imports
src_dir = project_dir / "src"
if str(src_dir) not in sys.path:
    sys.path.insert(0, str(src_dir))

# Set environment for dev testing
os.environ['REPORT_ENV'] = 'prod'

# %%
import src.config
from deltalake import DeltaTable
from pathlib import Path
import pandas as pd
from datetime import datetime, timezone

# %%
TABLE_PATH = src.config.SILVER / "account"

# %%
history = DeltaTable(TABLE_PATH).properties()
history_df = pd.DataFrame(history)

# %%
history_df

# %%
def convert_ts(ts):
    if len(str(ts)) == 13:
        return pd.to_datetime(ts, unit='ms', utc=True)
    else:
        return pd.to_datetime(ts, unit='s', utc=True)

history_df['readable_time'] = history_df['timestamp'].apply(convert_ts)

# %%
history_df['eastern_time'] = history_df['readable_time'].dt.tz_convert('America/New_York')

# %%
history_df
# Out:
#         timestamp operation    operationParameters         engineInfo  \
# 0   1757339595692     WRITE  {'mode': 'Overwrite'}  delta-rs:py-1.1.4
# 1   1757099540384     WRITE  {'mode': 'Overwrite'}  delta-rs:py-1.1.4
# 2   1756986006614     WRITE  {'mode': 'Overwrite'}  delta-rs:py-1.1.4
# 3   1756907559989     WRITE  {'mode': 'Overwrite'}  delta-rs:py-1.1.4
# 4   1756817406358     WRITE  {'mode': 'Overwrite'}  delta-rs:py-1.1.4
# 5   1756484063757     WRITE  {'mode': 'Overwrite'}  delta-rs:py-1.1.4
# 6   1756472683898     WRITE  {'mode': 'Overwrite'}  delta-rs:py-1.1.4
# 7   1756413101513     WRITE  {'mode': 'Overwrite'}  delta-rs:py-1.1.4
# 8   1756401511698     WRITE  {'mode': 'Overwrite'}  delta-rs:py-1.1.4
# 9   1756382988001     WRITE  {'mode': 'Overwrite'}  delta-rs:py-1.1.4
# 10  1756317371572     WRITE  {'mode': 'Overwrite'}  delta-rs:py-1.1.4
# 11  1756219465899     WRITE  {'mode': 'Overwrite'}  delta-rs:py-1.1.4
# ...

# %%
df = DeltaTable(TABLE_PATH, version=8).to_pandas()

# %%
df = DeltaTable(TABLE_PATH, version=8).pro

# %%
df['eastern_time'] = df['load_timestamp_utc'].dt.tz_convert('America/New_York')

# %%
df
# Out:
#          effdate    acctnbr  \
# 0     2025-08-29  150200005
# 1     2025-08-29  150586025
# 2     2025-08-29  150887241
# 3     2025-08-29   60801557
# 4     2025-08-29  151058057
# ...          ...        ...
# 89568 2025-08-29  150342956
# 89569 2025-08-29   23003040
# 89570 2025-08-29   27039064
# 89571 2025-08-29   27020568
# 89572 2025-08-29  150337783
#
#                                            ownersortname  \
# 0                          MONEYGRAM PAYMENT SYSTEMS INC
# 1                               GREATER FALL RIVER V.S.D
# 2                                        CITY OF TAUNTON
# 3      COMMUNITY COUNSELING OF BRISTOL COUNTY, INCORP...
# 4                                     NBPIV SARATOGA LLC
# ...                                                  ...
# 89568                            PATENAUDE, EDWARD H. JR
# 89569                                   LOPES, RONALD A.
# 89570                        BRISTOL COUNTY SAVINGS BANK
# ...

# %%
from deltalake import write_deltalake, CommitProperties
 
print("Starting address ...")
SAMPLE_PATH = Path(r"C:\Users\w322800\Documents\gh\bcsb-prod\Reports\Data Analytics\Lakehouse_v1\bin") / "address"
SAMPLE_PATH.mkdir(parents=True, exist_ok=True)

cp = CommitProperties(custom_metadata={"effdate":"2025-09-08"})
write_deltalake(SAMPLE_PATH, df, mode='overwrite', schema_mode='merge', commit_properties=cp)
print("Successfully wrote data")
# Out:
# Starting address ...
# Successfully wrote data

# %%
df = DeltaTable(SAMPLE_PATH).history()

# %%
df
# Out:
# [{'timestamp': 1757363800857,
#   'operation': 'WRITE',
#   'operationParameters': {'mode': 'Overwrite'},
#   'engineInfo': 'delta-rs:py-1.1.4',
#   'operationMetrics': {'execution_time_ms': 428,
#    'num_added_files': 1,
#    'num_added_rows': 89573,
#    'num_partitions': 0,
#    'num_removed_files': 0},
#   'clientVersion': 'delta-rs.py-1.1.4',
#   'effdate': '2025-09-08',
#   'version': 0}]
