# %%
import os
import sys
from pathlib import Path

# Navigate to project root (equivalent to cd ..)
project_dir = Path(__file__).parent.parent if '__file__' in globals() else Path.cwd().parent
os.chdir(project_dir)

# Add src directory to Python path for imports
src_dir = project_dir / "src"
if str(src_dir) not in sys.path:
    sys.path.insert(0, str(src_dir))

# Set environment for dev testing
os.environ['REPORT_ENV'] = 'prod'

# %%
import src.config
from deltalake import DeltaTable
from pathlib import Path
import pandas as pd

# %%
# TABLE_PATH = src.config.BRONZE / "metadata_lookup_engine1"
TABLE_PATH = src.config.SILVER / "account"

# %%
account = DeltaTable(TABLE_PATH).to_pandas()

# %%
account
# Out:
#          effdate    acctnbr  \
# 0     2025-08-26  150200005
# 1     2025-08-26  150586025
# 2     2025-08-26  150887241
# 3     2025-08-26   60801557
# 4     2025-08-26  151058057
# ...          ...        ...
# 89567 2025-08-26   27094715
# 89568 2025-08-26   23003040
# 89569 2025-08-26   27039064
# 89570 2025-08-26  150337783
# 89571 2025-08-26   27020568
#
#                                            ownersortname  \
# 0                          MONEYGRAM PAYMENT SYSTEMS INC
# 1                               GREATER FALL RIVER V.S.D
# 2                                        CITY OF TAUNTON
# 3      COMMUNITY COUNSELING OF BRISTOL COUNTY, INCORP...
# 4                                     NBPIV SARATOGA LLC
# ...                                                  ...
# 89567                               F & B RUBBERIZED INC
# 89568                                   LOPES, RONALD A.
# 89569                        BRISTOL COUNTY SAVINGS BANK
# 89570                        BRISTOL COUNTY SAVINGS BANK
# 89571                        BRISTOL COUNTY SAVINGS BANK
#
#                             product  noteopenamt ratetypcd mjaccttypcd  \
# 0                 Treasurer's Check          0.0      None        BKCK
# 1                     Municipal Now          0.0       VAR          CK
# 2      ICS Shadow - Muni - MMDA/SAV          0.0      None          CK
# 3      Investment Business Checking          0.0       VAR          CK
# 4              Commercial Mortgages   26000000.0       FIX         CML
# ...                             ...          ...       ...         ...
# 89567        Free Business Checking          0.0      None          CK
# 89568                  NOW Checking          0.0       VAR          CK
# 89569      Escrow Checks Processing          0.0      None        BKCK
# 89570             Business Checking          0.0      None          CK
# 89571              PDO Checks - OLD          0.0      None        BKCK
#
#       currmiaccttypcd curracctstatcd  noteintrate  ...  portfolio_key  \
# 0                TRCK            ACT       0.0000  ...          41513
# 1                CK27            ACT       0.0003  ...          40674
# 2                CK42            ACT       0.0000  ...           4183
# 3                CK28            ACT       0.0220  ...           3544
# 4                CM40            ACT       0.0635  ...          79205
# ...               ...            ...          ...  ...            ...
# 89567            CK25            ACT       0.0000  ...           3994
# 89568            CK05            ACT       0.0003  ...          33093
# 89569            BTC3            ACT       0.0000  ...           1222
# 89570            CK12            ACT       0.0000  ...           1222
# 89571            BTC1            ACT       0.0000  ...           1222
#
#        ownership_key address_key householdnbr       datelastmaint  Category  \
# 0            43261.0     44260.0     187340.0 2020-02-26 23:28:03      None
# 1            42158.0     43236.0     185474.0 2021-03-25 22:19:28      None
# 2            33668.0     33967.0          NaN                 NaT      None
# 3             3742.0      3878.0     280467.0 2024-02-14 11:54:44      None
# 4            83546.0     85431.0     288455.0 2024-06-11 12:02:04       CRE
# ...              ...         ...          ...                 ...       ...
# 89567         4207.0      4430.0     184909.0 2020-02-26 23:28:13      None
# 89568        33730.0     34038.0     141782.0 2020-02-26 23:28:12      None
# 89569         1352.0     41577.0     255924.0 2022-09-27 22:46:27      None
# 89570         1352.0     51094.0     255924.0 2022-09-27 22:46:27      None
# 89571         1352.0     41437.0     255924.0 2022-09-27 22:46:27      None
#
#       inactivedate                      branchname  primaryownercity  \
# 0              NaT              BCSB - MAIN OFFICE       MINNEAPOLIS
# 1              NaT   BCSB - MUNI FALL RIVER BRANCH        FALL RIVER
# 2              NaT         BCSB - MUNI MAIN OFFICE           TAUNTON
# 3              NaT              BCSB - MAIN OFFICE           TAUNTON
# 4              NaT  BCSB - COMM'L LENDING- TAUNTON         WAKEFIELD
# ...            ...                             ...               ...
# 89567          NaT       BCSB - CANDLEWORKS BRANCH       NEW BEDFORD
# 89568          NaT    BCSB - RAYNHAM CENTER BRANCH           RAYNHAM
# 89569          NaT              BCSB - MAIN OFFICE           TAUNTON
# 89570          NaT       BCSB - DEPOSIT OPERATIONS           TAUNTON
# 89571          NaT              BCSB - MAIN OFFICE           TAUNTON
#
#       primaryownerstate
# 0                    MN
# 1                    MA
# 2                    MA
# 3                    MA
# 4                    MA
# ...                 ...
# 89567                MA
# 89568                MA
# 89569                MA
# 89570                MA
# 89571                MA
#
# [89572 rows x 51 columns]

# %%
TABLE_PATH = src.config.BRONZE / "acctpropins"
acctpropins = DeltaTable(TABLE_PATH).to_pandas()

# %%
acctpropins
# Out:
#         acctnbr  propnbr  intrpolicynbr    effdate inactivedate  \
# 0     201342911    30221           4213 2019-05-01          NaT
# 1     150426875    50221           5446 2020-02-05          NaT
# 2     201754331    32082           5694 2020-03-11          NaT
# 3     150439381    50885           5697 2020-05-01          NaT
# 4     150439381    50885           5698 2020-03-12          NaT
# ...         ...      ...            ...        ...          ...
# 8508  150741380    71134          10485 2022-05-02          NaT
# 8509  150773896    73616          11646 2022-07-29          NaT
# 8510  150243584    40256          11764 2022-08-15          NaT
# 8511  201253881    29920          11807 2022-08-17          NaT
# 8512  150791161    74725          12084 2022-09-12          NaT
#
#            datelastmaint escrowyn lenderfundedyn escdisbchangeeffdate
# 0    2025-04-28 07:46:30        Y              N           2019-05-01
# 1    2020-07-26 23:28:41        Y              N           2021-02-01
# 2    2020-07-26 23:28:41        Y              N           2020-03-01
# 3    2023-02-13 10:53:20        Y              N           2020-05-01
# 4    2024-12-17 14:41:00        N              N           2021-02-01
# ...                  ...      ...            ...                  ...
# 8508 2025-08-26 11:05:40        Y              N           2022-08-01
# 8509 2025-07-07 08:41:19        Y              N           2023-07-01
# 8510 2025-07-23 10:12:06        Y              N           2023-07-01
# 8511 2024-08-20 08:24:20        Y              N           2023-08-01
# 8512 2025-08-26 12:36:31        Y              N           2023-08-01
#
# [8513 rows x 9 columns]

# %%
TABLE_PATH = src.config.BRONZE / "wh_inspolicy"
wh_inspolicy = DeltaTable(TABLE_PATH).to_pandas()

# %%
wh_inspolicy['instypdesc'].unique()
# Out:
# array(["Homeowner's Insurance", "Builder's Risk Insurance",
#        'Condominium Insurance', 'Flood Insurance', 'Commercial Insurance',
#        'Contents Insurance', 'Force Placed Flood Insurance',
#        'Force Placed Hazard Insurance', 'Private Mortgage Insurance',
#        'Liability Insurance'], dtype=object)
